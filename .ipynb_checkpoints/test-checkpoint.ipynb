# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import pandas as pd       
train = pd.read_csv("labeledTrainData.tsv", header=0, delimiter="\t", quoting=3)

# %%
train.shape
# Out:
# (25000, 3)

# %%
train.columns.values
# Out:
# array(['id', 'sentiment', 'review'], dtype=object)

# %%
train["review"][0]
# Out:
# '"With all this stuff going down at the moment with MJ i\'ve started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ\'s feeling towards the press and also the obvious message of drugs are bad m\'kay.<br /><br />Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.<br /><br />The actual feature film bit when it finally starts is only on for 20 minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord. Why he wants MJ dead so bad is beyond me. Because MJ overheard his plans? Nah, Joe Pesci\'s character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno, maybe he just hates MJ\'s music.<br /><br />Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence. Also, the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene.<br /><br />Bottom line, this movie is for people who like MJ on one level or another (which i think is most people). If not, then stay away. It does try and give off a wholesome message and ironically MJ\'s bestest buddy in this movie is a girl! Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty? Well, with all the attention i\'ve gave this subject....hmmm well i don\'t know because people can be different behind closed doors, i know this for a fact. He is either an extremely nice but stupid guy or one of the most sickest liars. I hope he is not the latter."'

# %%
# Import BeautifulSoup into your workspace
from bs4 import BeautifulSoup             

# Initialize the BeautifulSoup object on a single movie review     
example1 = BeautifulSoup(train["review"][0])  

# Print the raw review and then the output of get_text(), for 
# comparison
print (example1.get_text())
# Out:
# "With all this stuff going down at the moment with MJ i've started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ's feeling towards the press and also the obvious message of drugs are bad m'kay.Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.The actual feature film bit when it finally starts is only on for 20 minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord. Why he wants MJ dead so bad is beyond me. Because MJ overheard his plans? Nah, Joe Pesci's character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno, maybe he just hates MJ's music.Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence. Also, the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene.Bottom line, this movie is for people who like MJ on one level or another (which i think is most people). If not, then stay away. It does try and give off a wholesome message and ironically MJ's bestest buddy in this movie is a girl! Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty? Well, with all the attention i've gave this subject....hmmm well i don't know because people can be different behind closed doors, i know this for a fact. He is either an extremely nice but stupid guy or one of the most sickest liars. I hope he is not the latter."
# C:\Users\TANGP05\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
import re
# Use regular expressions to do a find-and-replace
letters_only = re.sub("[^a-zA-Z]",           # The pattern to search for
                      " ",                   # The pattern to replace it with
                      example1.get_text() )  # The text to search
print (letters_only)
# Out:
#  With all this stuff going down at the moment with MJ i ve started listening to his music  watching the odd documentary here and there  watched The Wiz and watched Moonwalker again  Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent  Moonwalker is part biography  part feature film which i remember going to see at the cinema when it was originally released  Some of it has subtle messages about MJ s feeling towards the press and also the obvious message of drugs are bad m kay Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring  Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him The actual feature film bit when it finally starts is only on for    minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord  Why he wants MJ dead so bad is beyond me  Because MJ overheard his plans  Nah  Joe Pesci s character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno  maybe he just hates MJ s music Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence  Also  the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene Bottom line  this movie is for people who like MJ on one level or another  which i think is most people   If not  then stay away  It does try and give off a wholesome message and ironically MJ s bestest buddy in this movie is a girl  Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty  Well  with all the attention i ve gave this subject    hmmm well i don t know because people can be different behind closed doors  i know this for a fact  He is either an extremely nice but stupid guy or one of the most sickest liars  I hope he is not the latter

# %%
import nltk
from nltk.corpus import stopwords # Import the stop word list
print (stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

# %%
stemmer=nltk.PorterStemmer()

def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    
    #### Add word stemmer
    
    meaningful_words_stem=[stemmer.stem(t) for t in meaningful_words]  
    
    return( " ".join( meaningful_words_stem ))

# %%
clean_review = review_to_words( train["review"][0] )
print (clean_review)
# Out:
# C:\Users\TANGP05\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# stuff go moment mj start listen music watch odd documentari watch wiz watch moonwalk mayb want get certain insight guy thought realli cool eighti mayb make mind whether guilti innoc moonwalk part biographi part featur film rememb go see cinema origin releas subtl messag mj feel toward press also obviou messag drug bad kay visual impress cours michael jackson unless remot like mj anyway go hate find bore may call mj egotist consent make movi mj fan would say made fan true realli nice actual featur film bit final start minut exclud smooth crimin sequenc joe pesci convinc psychopath power drug lord want mj dead bad beyond mj overheard plan nah joe pesci charact rant want peopl know suppli drug etc dunno mayb hate mj music lot cool thing like mj turn car robot whole speed demon sequenc also director must patienc saint came film kiddi bad sequenc usual director hate work one kid let alon whole bunch perform complex danc scene bottom line movi peopl like mj one level anoth think peopl stay away tri give wholesom messag iron mj bestest buddi movi girl michael jackson truli one talent peopl ever grace planet guilti well attent gave subject hmmm well know peopl differ behind close door know fact either extrem nice stupid guy one sickest liar hope latter

# %%
# Get the number of reviews based on the dataframe column size
num_reviews = train["review"].size

# Initialize an empty list to hold the clean reviews
clean_train_reviews = []

# Loop over each review; create an index i that goes from 0 to the length
# of the movie review list 
for i in range( 0, num_reviews ):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_reviews.append( review_to_words( train["review"][i] ) )
# Out:
# C:\Users\TANGP05\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
print ("Cleaning and parsing the training set movie reviews...\n")
clean_train_reviews = []
for i in range( 0, num_reviews ):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print ("Review %d of %d\n" % ( i+1, num_reviews ))                                                                    
    clean_train_reviews.append( review_to_words( train["review"][i] ))
# Out:
# Cleaning and parsing the training set movie reviews...
# C:\Users\TANGP05\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Review 1000 of 25000
#
# Review 2000 of 25000
#
# Review 3000 of 25000
#
# Review 4000 of 25000
#
# Review 5000 of 25000
#
# Review 6000 of 25000
#
# Review 7000 of 25000
#
# Review 8000 of 25000
#
# Review 9000 of 25000
#
# Review 10000 of 25000
#
# Review 11000 of 25000
#
# Review 12000 of 25000
#
# Review 13000 of 25000
#
# Review 14000 of 25000
#
# Review 15000 of 25000
#
# Review 16000 of 25000
#
# Review 17000 of 25000
#
# Review 18000 of 25000
#
# Review 19000 of 25000
#
# Review 20000 of 25000
#
# Review 21000 of 25000
#
# Review 22000 of 25000
#
# Review 23000 of 25000
#
# Review 24000 of 25000
#
# Review 25000 of 25000

# %%
from sklearn.cross_validation import train_test_split
size=0.1
seed=1
train_review,test_review,train_sentiment,test_sentiment= train_test_split(clean_train_reviews,train["sentiment"], test_size=size, random_state=seed)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(train_review)
test_data_features = vectorizer.fit_transform(test_review)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
test_data_features = test_data_features.toarray()

# %%
print (train_data_features.shape)
print (test_data_features.shape)
# Out:
# (22500, 5000)
# (2500, 5000)

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print (vocab)
# Out:
# ['abandon', 'abc', 'abil', 'abl', 'abomin', 'aborigin', 'abort', 'abound', 'abraham', 'abrupt', 'absenc', 'absent', 'absolut', 'absorb', 'absurd', 'abund', 'abus', 'abysm', 'academi', 'accent', 'accept', 'access', 'accid', 'accident', 'acclaim', 'accompani', 'accomplish', 'accord', 'account', 'accur', 'accuraci', 'accus', 'ace', 'achiev', 'acid', 'acknowledg', 'acquaint', 'acquir', 'across', 'act', 'action', 'activ', 'actor', 'actress', 'actual', 'ad', 'adam', 'adapt', 'add', 'addict', 'addit', 'address', 'adequ', 'admir', 'admit', 'admittedli', 'adolesc', 'adopt', 'ador', 'adult', 'advanc', 'advantag', 'adventur', 'advertis', 'advic', 'advis', 'aesthet', 'affair', 'affect', 'affleck', 'afford', 'aforement', 'afraid', 'africa', 'african', 'afternoon', 'afterward', 'age', 'agenc', 'agenda', 'agent', 'aggress', 'ago', 'agre', 'ah', 'ahead', 'aid', 'aim', 'air', 'airplan', 'airport', 'aka', 'akin', 'akshay', 'al', 'ala', 'alan', 'alarm', 'albeit', 'albert', 'album', 'alcohol', 'alec', 'alert', 'alex', 'alexand', 'alexandr', 'alfr', 'alic', 'alicia', 'alien', 'alik', 'alison', 'aliv', 'alleg', 'allen', 'alley', 'alli', 'allow', 'almost', 'alon', 'along', 'alongsid', 'alreadi', 'alright', 'also', 'alter', 'altern', 'although', 'altman', 'altogeth', 'alvin', 'alway', 'amanda', 'amateur', 'amateurish', 'amaz', 'amazingli', 'amazon', 'ambigu', 'ambit', 'ambiti', 'america', 'american', 'ami', 'amitabh', 'among', 'amongst', 'amor', 'amount', 'amrita', 'amus', 'analysi', 'analyz', 'anchor', 'ancient', 'anderson', 'andi', 'andr', 'andrew', 'angel', 'angela', 'anger', 'angl', 'angri', 'angst', 'anim', 'ann', 'anna', 'anni', 'announc', 'annoy', 'anoth', 'answer', 'ant', 'antagonist', 'antholog', 'anthoni', 'anti', 'antic', 'anticip', 'anton', 'antonio', 'antonioni', 'antwon', 'anybodi', 'anymor', 'anyon', 'anyth', 'anyway', 'anywher', 'apart', 'ape', 'apolog', 'appal', 'appar', 'appeal', 'appear', 'appl', 'applaud', 'appli', 'appreci', 'approach', 'appropri', 'approv', 'april', 'arab', 'arc', 'archiv', 'area', 'argu', 'arguabl', 'argument', 'ariel', 'aris', 'aristocrat', 'arm', 'armi', 'armstrong', 'arnold', 'around', 'arquett', 'arrang', 'arrest', 'arriv', 'arrog', 'arrow', 'art', 'arthur', 'articl', 'artifici', 'artist', 'artsi', 'artwork', 'ash', 'asham', 'ashley', 'asian', 'asid', 'ask', 'asleep', 'aspect', 'aspir', 'ass', 'assassin', 'assault', 'assembl', 'assert', 'asset', 'assign', 'assist', 'associ', 'assum', 'assur', 'astair', 'astonish', 'astound', 'astronaut', 'asylum', 'athlet', 'atlanti', 'atmospher', 'atroc', 'atroci', 'attach', 'attack', 'attempt', 'attenborough', 'attend', 'attent', 'attitud', 'attorney', 'attract', 'attribut', 'audienc', 'audio', 'audit', 'audrey', 'aunt', 'aussi', 'austen', 'austin', 'australia', 'australian', 'authent', 'author', 'automat', 'avail', 'aveng', 'averag', 'avoid', 'aw', 'await', 'awak', 'awaken', 'awar', 'award', 'away', 'awe', 'awesom', 'awhil', 'awkward', 'axe', 'babe', 'babi', 'bacal', 'bachelor', 'back', 'backdrop', 'background', 'backward', 'bacon', 'bad', 'baddi', 'badli', 'baffl', 'bag', 'bait', 'bake', 'baker', 'bakshi', 'balanc', 'baldwin', 'ball', 'ballet', 'ban', 'banal', 'band', 'bang', 'bank', 'banter', 'bar', 'barbara', 'bare', 'bargain', 'barn', 'barrel', 'barri', 'barrymor', 'base', 'basebal', 'basement', 'bash', 'basi', 'basic', 'basing', 'basket', 'basketbal', 'bastard', 'bat', 'bate', 'bath', 'bathroom', 'batman', 'battl', 'bay', 'bbc', 'be', 'beach', 'bean', 'bear', 'beard', 'beast', 'beat', 'beaten', 'beatl', 'beatti', 'beauti', 'becam', 'becom', 'bed', 'bedroom', 'beer', 'befriend', 'beg', 'began', 'begin', 'behav', 'behavior', 'behaviour', 'behind', 'behold', 'bela', 'belief', 'believ', 'bell', 'belli', 'belong', 'belov', 'belt', 'belushi', 'ben', 'bend', 'beneath', 'benefit', 'bent', 'beowulf', 'bergman', 'berkeley', 'berlin', 'bernard', 'besid', 'best', 'bet', 'betray', 'bett', 'better', 'betti', 'beverli', 'bewar', 'beyond', 'bias', 'bibl', 'biblic', 'big', 'bigger', ...

# %%
import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print (count, tag)
# Out:
# 255 abandon
# 119 abc
# 507 abil
# 1139 abl
# 71 abomin
# 59 aborigin
# 84 abort
# 56 abound
# 86 abraham
# 62 abrupt
# 105 absenc
# 75 absent
# 1668 absolut
# 147 absorb
# 373 absurd
# 62 abund
# 342 abus
# 98 abysm
# 263 academi
# 634 accent
# 701 accept
# 147 access
# 318 accid
# 220 accident
# 112 acclaim
# 184 accompani
# 234 accomplish
# 277 accord
# 269 account
# 318 accur
# 72 accuraci
# 183 accus
# 68 ace
# 521 achiev
# 98 acid
# 96 acknowledg
# 63 acquaint
# 87 acquir
# 871 across
# 7964 act
# 3372 action
# 251 activ
# 6169 actor
# 1408 actress
# 4554 actual
# 715 ad
# 357 adam
# 754 adapt
# 1063 add
# 229 addict
# 448 addit
# 167 address
# 128 adequ
# 403 admir
# 661 admit
# 123 admittedli
# 100 adolesc
# 141 adopt
# 207 ador
# 792 adult
# 244 advanc
# 154 advantag
# 707 adventur
# 209 advertis
# 231 advic
# 176 advis
# 68 aesthet
# 378 affair
# 403 affect
# 62 affleck
# 126 afford
# 115 aforement
# 311 afraid
# 200 africa
# 259 african
# 177 afternoon
# 170 afterward
# 1558 age
# 68 agenc
# 83 agenda
# 398 agent
# 97 aggress
# 941 ago
# 712 agre
# 107 ah
# 359 ahead
# 260 aid
# 296 aim
# 753 air
# 89 airplan
# 88 airport
# 169 aka
# 67 akin
# 106 akshay
# 339 al
# 184 ala
# 313 alan
# 80 alarm
# 141 albeit
# 241 albert
# 103 album
# 199 alcohol
# 74 alec
# 96 alert
# 224 alex
# 104 alexand
# 65 alexandr
# 88 alfr
# 186 alic
# 74 alicia
# 638 alien
# 139 alik
# 79 alison
# 416 aliv
# 59 alleg
# 365 allen
# 75 alley
# 124 alli
# 932 allow
# 2824 almost
# 953 alon
# 1599 along
# 78 alongsid
# 1238 alreadi
# 160 alright
# 8265 also
# 160 alter
# 221 altern
# 2276 although
# 106 altman
# 103 altogeth
# 65 alvin
# 2923 alway
# 91 amanda
# 229 amateur
# 206 amateurish
# 1418 amaz
# 160 amazingli
# 75 amazon
# 126 ambigu
# 108 ambit
# 124 ambiti
# 666 america
# 2359 american
# 109 ami
# 86 amitabh
# 713 among
# 146 amongst
# 66 amor
# 550 amount
# 60 amrita
# 641 amus
# 77 analysi
# 69 analyz
# 78 anchor
# 220 ancient
# 209 anderson
# 310 andi
# 86 andr
# 273 andrew
# 453 angel
# 81 angela
# 200 anger
# 371 angl
# 306 angri
# 64 angst
# 2242 anim
# 456 ann
# 236 anna
# 107 anni
# 132 announc
# 1161 annoy
# 3900 anoth
# 559 answer
# 103 ant
# 65 antagonist
# 63 antholog
# 231 anthoni
# 438 anti
# 108 antic
# 152 anticip
# 67 anton
# 55 antonio
# 77 antonioni
# 87 antwon
# 283 anybodi
# 298 anymor
# 2377 anyon
# 2657 anyth
# 1106 anyway
# 273 anywher
# 884 apart
# 215 ape
# 103 apolog
# 145 appal
# 1111 appar
# 667 appeal
# 2326 appear
# 55 appl
# 94 applaud
# 144 appli
# 780 appreci
# 508 approach
# 282 appropri
# 75 approv
# 95 april
# 92 arab
# 83 arc
# 62 archiv
# 406 area
# 184 argu
# 88 arguabl
# 158 argument
# 61 ariel
# 58 aris
# 76 aristocrat
# 387 arm
# 431 armi
# 59 armstrong
# 134 arnold
# 3267 around
# 54 arquett
# 136 arrang
# 190 arrest
# 456 arriv
# 131 arrog
# 74 arrow
# 1488 art
# 321 arthur
# 64 articl
# 115 artifici
# 817 artist
# 63 artsi
# 62 artwork
# 58 ash
# 149 asham
# 83 ashley
# 235 asian
# 434 asid
# 1346 ask
# 198 asleep
# 777 aspect
# 138 aspir
# 257 ass
# 184 assassin
# 118 assault
# 102 assembl
# 63 assert
# 59 asset
# 143 assign
# 240 assist
# 231 associ
# 381 assum
# 125 assur
# 125 astair
# 105 astonish
# 67 astound
# 65 astronaut
# 75 asylum
# 67 athlet
# 103 atlanti
# 832 atmospher
# 66 atroc
# 188 atroci
# 176 attach
# 761 attack
# 1737 attempt
# 71 attenborough
# 254 attend
# 842 attent
# 296 attitud
# 80 attorney
# 660 attract
# 77 attribut
# 2395 audienc
# 109 audio
# 104 audit
# 60 audrey
# 185 aunt
# 59 aussi
# 85 austen
# 72 austin
# 115 australia
# 199 australian
# 218 authent
# 436 author
# 108 automat
# 376 avail
# 100 aveng
# 646 averag
# 895 avoid
# 1701 aw
# 95 await
# 103 awak
# 106 awaken
# 295 awar
# 623 award
# 2530 away
# 109 awe
# 475 awesom
# 74 awhil
# 235 awkward
# 64 axe
# 130 babe
# 706 babi
# 82 bacal
# 63 bachelor
# 4659 back
# 129 backdrop
# 644 background
# 87 backward
# 64 bacon
# 8511 bad
# 80 baddi
# 598 badli
# 66 baffl
# 169 bag
# 61 bait
# 72 bake
# 138 baker
# 131 bakshi
# 238 balanc
# 74 baldwin
# 340 ball
# 87 ballet
# 134 ban
# 88 banal
# 558 band
# 140 bang
# 296 bank
# 64 banter
# 434 bar
# 221 barbara
# 565 bare
# 104 bargain
# 60 barn
# 76 barrel
# 132 barri
# 82 barrymor
# 1497 base
# 186 basebal
# 128 basement
# 111 bash
# 148 basi
# 1332 basic
# 64 basing
# 56 basket
# 79 basketbal
# 59 bastard
# 207 bat
# 62 bate
# 142 bath
# 107 bathroom
# 396 batman
# 730 battl
# 85 bay
# 166 bbc
# 113 be
# 204 beach
# 70 bean
# 405 bear
# 68 beard
# 182 beast
# 567 beat
# 109 beaten
# 80 beatl
# 100 beatti
# 2945 beauti
# 628 becam
# 2881 becom
# 380 bed
# 104 bedroom
# 156 beer
# 95 befriend
# 168 beg
# 278 began
# 2654 begin
# 172 behav
# 262 behavior
# 69 behaviour
# 1178 behind
# 70 behold
# 66 bela
# 254 belief
# 3523 believ
# 160 bell
# 62 belli
# 259 belong
# 158 belov
# 91 belt
# 80 belushi
# 556 ben
# 82 bend
# 99 beneath
# 152 benefit
# 61 bent
# 60 beowulf
# 90 bergman
# 58 berkeley
# 85 berlin
# 73 bernard
# 434 besid
# 5793 best
# 249 bet
# 177 betray
# 143 bett
# 5176 better
# 228 betti
# 71 beverli
# 65 bewar
# 802 beyond
# 65 bias
# 123 bibl
# 64 biblic
# 3139 big
# 241 bigger
# 464 biggest
# 75 bike
# 66 biker
# 62 bikini
# 78 biko
# 719 bill
# 360 billi
# 105 bin
# 93 biographi
# 56 biopic
# 219 bird
# 185 birth
# 121 birthday
# 2974 bit
# 92 bitch
# 193 bite
# 66 bitten
# 168 bitter
# 486 bizarr
# 1909 black
# 78 blackmail
# 106 blade
# 160 blah
# 158 blair
# 104 blake
# 351 blame
# 291 bland
# 135 blank
# 117 blast
# 92 blatant
# 57 blatantli
# 120 bleak
# 88 bleed
# 178 blend
# 105 bless
# 96 blew
# 283 blind
# 118 blob
# 154 block
# 215 blockbust
# 351 blond
# 1118 blood
# 278 bloodi
# 71 bloom
# 56 blossom
# 400 blow
# 170 blown
# 478 blue
# 83 blunt
# 60 blur
# 142 bo
# 298 board
# 103 boast
# 254 boat
# 255 bob
# 131 bobbi
# 1087 bodi
# 56 bogart
# 59 bogu
# 113 boil
# 97 bold
# 127 boll
# 155 bollywood
# 346 bomb
# 369 bond
# 61 bondag
# 162 bone
# 88 bonu
# 59 boo
# 64 boob
# 2649 book
# 93 boom
# 131 boot
# 57 booth
# 184 border
# 2291 bore
# 128 boredom
# 55 bori
# 357 born
# 174 borrow
# 426 boss
# 66 boston
# 591 bother
# 102 bottl
# 382 bottom
# 418 bought
# 65 bounc
# 190 bound
# 57 bounti
# 187 bourn
# 91 bow
# 97 bowl
# 743 box
# 82 boxer
# 2006 boy
# 64 boyer
# 383 boyfriend
# 67 boyl
# 163 brad
# 99 bradi
# 550 brain
# 160 branagh
# 138 brand
# 129 brando
# 57 brat
# 208 brave
# 63 braveheart
# 55 bravo
# 103 brazil
# 68 bread
# 1014 break
# 56 breakdown
# 62 breakfast
# 174 breast
# 274 breath
# 154 breathtak
# 93 breed
# 74 brenda
# 64 brendan
# 313 brian
# 152 bride
# 205 bridg
# 70 bridget
# 371 brief
# 117 briefli
# 249 bright
# 117 brillianc
# 1086 brilliant
# 223 brilliantli
# 1560 bring
# 67 brit
# 138 britain
# 817 british
# 80 bro
# 105 broad
# 146 broadcast
# 215 broadway
# 139 broke
# 253 broken
# 64 bronson
# 57 bront
# 66 brood
# 217 brook
# 99 brooklyn
# 101 brosnan
# 1492 brother
# 688 brought
# 280 brown
# 357 bruce
# 57 bruno
# 60 brush
# 442 brutal
# 60 btw
# 173 bu
# 98 bubbl
# 277 buck
# 124 bud
# 314 buddi
# 1738 budget
# 179 buff
# 87 buffalo
# 256 bug
# 830 build
# 207 built
# 58 bulk
# 108 bull
# 201 bullet
# 146 bulli
# 88 bumbl
# 82 bump
# 750 bunch
# 77 bunni
# 176 buri
# 59 burk
# 526 burn
# 125 burst
# 144 burt
# 143 burton
# 57 busey
# 132 bush
# 735 busi
# 69 businessman
# 103 bust
# 80 buster
# 117 butcher
# 76 butler
# 132 butt
# 127 button
# 889 buy
# 69 buzz
# 67 bye
# 163 cabin
# 254 cabl
# 299 cage
# 121 cagney
# 225 cain
# 100 cake
# 56 cal
# 75 calib
# 170 california
# 2502 call
# 88 calm
# 65 camcord
# 1497 came
# 356 cameo
# 1720 camera
# 113 cameron
# 507 camp
# 76 campaign
# 95 campbel
# 173 campi
# 123 canada
# 218 canadian
# 135 cancel
# 65 cancer
# 266 candi
# 104 candid
# 62 candl
# 142 cannib
# 82 cannon
# 989 cannot
# 185 cant
# 73 canyon
# 73 cap
# 256 capabl
# 153 capit
# 300 captain
# 221 captiv
# 764 captur
# 1357 car
# 230 card
# 109 cardboard
# 1926 care
# 1002 career
# 72 carel
# 56 caretak
# 61 carey
# 93 cari
# 133 caricatur
# 100 carl
# 73 carla
# 72 carlito
# 60 carlo
# 61 carmen
# 163 carol
# 153 carpent
# 82 carradin
# 125 carrey
# 833 carri
# 136 carter
# 691 cartoon
# 60 cartoonish
# 1561 case
# 232 cash
# 57 casino
# 58 cassavet
# 80 cassidi
# 4096 cast
# 318 castl
# 91 casual
# 620 cat
# 583 catch
# 79 catchi
# 231 categori
# 131 catherin
# 147 cathol
# 71 cattl
# 488 caught
# 928 caus
# 119 cave
# 64 cb
# 95 cd
# 57 cecil
# 339 celebr
# 201 cell
# 96 celluloid
# 62 cemeteri
# 76 censor
# 81 cent
# 408 center
# 101 centr
# 370 central
# 523 centuri
# 62 cerebr
# 56 ceremoni
# 683 certain
# 1318 certainli
# 83 cg
# 287 cgi
# 160 chain
# 75 chainsaw
# 174 chair
# 391 challeng
# 54 chamber
# 63 chamberlain
# 92 champion
# 81 championship
# 195 chan
# 1087 chanc
# 1856 chang
# 498 channel
# 105 chao
# 138 chaplin
# 117 chapter
# 12803 charact
# 183 character
# 64 characteris
# 99 characterist
# 281 charg
# 122 charisma
# 122 charismat
# 369 charl
# 379 charli
# 90 charlott
# 58 charlton
# 879 charm
# 735 chase
# 68 chavez
# 198 che
# 803 cheap
# 234 cheat
# 920 check
# 115 cheek
# 219 cheer
# 147 chees
# 609 cheesi
# 422 chemistri
# 60 cher
# 79 chess
# 102 chest
# 115 chew
# 82 chicago
# 289 chick
# 91 chicken
# 220 chief
# 1220 child
# 335 childhood
# 113 childish
# 1351 children
# 278 chill
# 168 china
# 307 chines
# 61 chip
# 633 choic
# 59 choke
# 340 choos
# 152 chop
# 69 choppi
# 132 choreograph
# 103 choreographi
# 87 choru
# 174 chose
# 217 chosen
# 395 chri
# 168 christ
# 146 christi
# 477 christian
# 71 christin
# 572 christma
# 386 christoph
# 80 chronicl
# 150 chuck
# 134 chuckl
# 402 church
# 54 churn
# 112 cia
# 73 cigarett
# 208 cinderella
# 1430 cinema
# 388 cinemat
# 144 cinematograph
# 885 cinematographi
# 147 circl
# 70 circu
# 220 circumst
# 1155 citi
# 182 citizen
# 247 civil
# 60 clad
# 525 claim
# 178 clair
# 66 clan
# 59 clara
# 263 clark
# 79 clash
# 918 class
# 1939 classic
# 72 clau
# 65 claud
# 61 claustrophob
# 54 clay
# 296 clean
# 741 clear
# 830 clearli
# 73 clerk
# 504 clever
# 83 cleverli
# 952 clich
# 71 click
# 58 client
# 117 cliff
# 63 cliffhang
# 89 climact
# 76 climat
# 398 climax
# 135 climb
# 63 clinic
# 96 clint
# 240 clip
# 116 clock
# 85 clone
# 1574 close
# 191 closer
# 84 closest
# 114 closet
# 439 cloth
# 77 cloud
# 119 clown
# 418 club
# 311 clue
# 62 clueless
# 97 clumsi
# 573 co
# 114 coach
# 83 coast
# 67 coaster
# 99 coat
# 253 code
# 101 coffe
# 61 cohen
# 138 coher
# 57 cohes
# 116 coincid
# 508 cold
# 123 cole
# 56 colin
# 101 collabor
# 94 collaps
# 92 colleagu
# 494 collect
# 58 collector
# 453 colleg
# 85 colonel
# 107 coloni
# 745 color
# 224 colour
# 204 columbo
# 212 com
# 57 comb
# 116 combat
# 567 combin
# 6045 come
# 55 comeback
# 285 comed
# 3309 comedi
# 220 comedian
# 237 comfort
# 1113 comic
# 268 command
# 93 commend
# 1521 comment
# 323 commentari
# 350 commerci
# 444 commit
# 466 common
# 487 commun
# 117 communist
# 535 compani
# 126 companion
# 966 compar
# 290 comparison
# 85 compass
# 453 compel
# 84 compens
# 261 compet
# 148 competit
# 246 complain
# 197 complaint
# 2748 complet
# 486 complex
# 253 complic
# 86 compliment
# 214 compos
# 88 composit
# 64 comprehend
# 59 comprehens
# 61 compris
# 73 compromis
# 503 comput
# 247 con
# 57 conan
# 155 conceiv
# 166 concentr
# 568 concept
# 563 concern
# 146 concert
# 138 conclud
# 491 conclus
# 82 condemn
# 234 condit
# 72 conduct
# 168 confess
# 178 confid
# 87 confin
# 101 confirm
# 381 conflict
# 261 confront
# 867 confus
# 56 congratul
# 593 connect
# 90 conneri
# 76 connor
# 64 conquer
# 55 conrad
# 73 conscienc
# 67 consciou
# 73 conscious
# 207 consequ
# 100 conserv
# 1432 consid
# 205 consider
# 435 consist
# 131 conspiraci
# 260 constant
# 388 constantli
# 58 constitut
# 224 construct
# 94 consum
# 176 contact
# 676 contain
# 90 contempl
# 221 contemporari
# 64 contempt
# 58 contend
# 363 content
# 187 contest
# 243 context
# 1040 continu
# 149 contract
# 76 contradict
# 104 contrari
# 270 contrast
# 224 contribut
# 247 contriv
# 627 control
# 178 controversi
# 113 conveni
# 278 convent
# 317 convers
# 66 convert
# 313 convey
# 215 convict
# 915 convinc
# 79 convincingli
# 113 convolut
# 201 cook
# 78 cooki
# 896 cool
# 180 cooper
# 847 cop
# 93 cope
# 659 copi
# 70 corbett
# 232 core
# 65 corman
# 60 corn
# 182 corner
# 240 corni
# 176 corpor
# 173 corps
# 276 correct
# 72 correctli
# 54 corridor
# 230 corrupt
# 420 cost
# 617 costum
# 72 couch
# 7147 could
# 445 count
# 95 counter
# 66 counterpart
# 123 countless
# 978 countri
# 91 countrysid
# 76 coup
# 1706 coupl
# 178 courag
# 2295 cours
# 211 court
# 167 cousin
# 836 cover
# 65 cow
# 213 cowboy
# 115 cox
# 232 crack
# 273 craft
# 113 craig
# 959 crap
# 225 crappi
# 324 crash
# 110 craven
# 74 crawford
# 72 crawl
# 93 craze
# 625 crazi
# 77 cream
# 1537 creat
# 149 creation
# 426 creativ
# 200 creator
# 503 creatur
# 295 credibl
# 1149 credit
# 54 creek
# 146 creep
# 611 creepi
# 519 crew
# 681 cri
# 785 crime
# 480 crimin
# 164 cring
# 74 crippl
# 132 crisi
# 56 crisp
# 970 critic
# 76 critiqu
# 92 crocodil
# 109 crook
# 56 crosbi
# 436 cross
# 79 crow
# 268 crowd
# 79 crown
# 83 crucial
# 183 crude
# 163 cruel
# 64 cruelti
# 132 cruis
# 171 crush
# 88 crystal
# 93 cuba
# 56 cuban
# 137 cube
# 92 cue
# 66 culmin
# 452 cult
# 689 cultur
# 56 cunningham
# 126 cup
# 131 cure
# 119 curios
# 238 curiou
# 71 curli
# 346 current
# 208 curs
# 55 curtain
# 117 curti
# 127 cusack
# 67 cush
# 111 custom
# 1362 cut
# 550 cute
# 54 cutter
# 85 cyborg
# 63 cycl
# 211 cynic
# 59 cypher
# 88 da
# 463 dad
# 94 daddi
# 153 daili
# 85 daisi
# 94 dalton
# 186 damag
# 59 dame
# 81 damm
# 412 damn
# 77 damon
# 231 dan
# 75 dana
# 1284 danc
# 242 dancer
# 68 dandi
# 129 dane
# 532 danger
# 309 daniel
# 63 danish
# 328 danni
# 275 dare
# 1409 dark
# 104 darker
# 71 darn
# 79 darren
# 118 dash
# 795 date
# 1194 daughter
# 112 dave
# 448 davi
# 908 david
# 142 dawn
# 125 dawson
# 3591 day
# 56 daylight
# 88 dazzl
# 720 de
# 1692 dead
# 180 deadli
# 75 deaf
# 1136 deal
# 88 dealer
# 116 dealt
# 170 dean
# 55 deanna
# 129 dear
# 1905 death
# 119 debat
# 68 debt
# 264 debut
# 443 decad
# 57 decapit
# 68 deceas
# 1051 decent
# 64 decept
# 1598 decid
# 55 decidedli
# 323 decis
# 113 declar
# 88 declin
# 97 decor
# 138 dedic
# 75 dee
# 89 deed
# 60 deem
# 601 deep
# 146 deeper
# 285 deepli
# 67 deer
# 192 defeat
# 173 defend
# 87 defens
# 105 defi
# 225 defin
# 1688 definit
# 75 degrad
# 227 degre
# 88 del
# 70 delet
# 153 deliber
# 72 delic
# 102 delici
# 496 delight
# 924 deliv
# 57 deliver
# 168 deliveri
# 74 delv
# 261 demand
# 82 dement
# 76 demis
# 408 demon
# 217 demonstr
# 199 deni
# 71 deniro
# 158 denni
# 153 dentist
# 132 denzel
# 249 depart
# 63 departur
# 222 depend
# 610 depict
# 428 depress
# 514 depth
# 57 deputi
# 87 der
# 69 derang
# 141 derek
# 121 deriv
# 95 descend
# 81 descent
# 666 describ
# 195 descript
# 304 desert
# 1112 deserv
# 672 design
# 457 desir
# 84 despair
# 546 desper
# 71 despic
# 70 despis
# 1216 despit
# 120 destin
# 104 destini
# 517 destroy
# 191 destruct
# 56 detach
# 793 detail
# 508 detect
# 251 determin
# 107 detract
# 98 devast
# 1455 develop
# 228 devic
# 304 devil
# 96 devoid
# 164 devot
# 829 dialog
# 1475 dialogu
# 138 diamond
# 94 dian
# 96 diana
# 62 diari
# 273 dick
# 95 dicken
# 81 dictat
# 1807 die
# 2690 differ
# 629 difficult
# 142 difficulti
# 200 dig
# 150 digit
# 110 digniti
# 60 dilemma
# 63 dim
# 103 dimens
# 244 dimension
# 77 din
# 135 dinner
# 198 dinosaur
# 114 dire
# 3431 direct
# 172 directli
# 4612 director
# 117 directori
# 67 dirt
# 308 dirti
# 81 disabl
# 136 disagre
# 311 disappear
# 1697 disappoint
# 316 disast
# 67 disastr
# 160 disbelief
# 126 disc
# 60 discern
# 782 discov
# 110 discoveri
# 366 discuss
# 137 diseas
# 92 disgrac
# 138 disguis
# 326 disgust
# 62 dish
# 85 disjoint
# 229 dislik
# 65 dismal
# 86 dismiss
# 688 disney
# 76 disord
# 418 display
# 83 dispos
# 63 disregard
# 55 disrespect
# 129 distanc
# 110 distant
# 168 distinct
# 80 distinguish
# 83 distort
# 275 distract
# 78 distress
# 137 distribut
# 586 disturb
# 95 dive
# 117 divers
# 73 divid
# 61 divin
# 156 divorc
# 70 dixon
# 57 dj
# 129 doc
# 620 doctor
# 134 document
# 975 documentari
# 812 dog
# 186 doll
# 332 dollar
# 82 dolph
# 100 domest
# 250 domin
# 89 domino
# 178 donald
# 2809 done
# 107 donna
# 64 dont
# 112 doo
# 178 doom
# 510 door
# 116 dorothi
# 98 dose
# 396 doubl
# 805 doubt
# 281 dougla
# 62 down
# 69 downey
# 89 downhil
# 168 downright
# 270 dozen
# 648 dr
# 114 dracula
# 480 drag
# 229 dragon
# 87 drain
# 79 drake
# 1393 drama
# 725 dramat
# 428 draw
# 387 drawn
# 329 dread
# 1075 dream
# 79 dreari
# 70 dreck
# 583 dress
# 227 drew
# 233 dri
# 78 drift
# 348 drink
# 78 drip
# 788 drive
# 115 drivel
# 220 driven
# 202 driver
# 55 drone
# 479 drop
# 73 drove
# 121 drown
# 678 drug
# 89 drum
# 286 drunk
# 107 drunken
# 436 dub
# 60 dubiou
# 82 duck
# 91 dud
# 192 dude
# 55 dudley
# 823 due
# 68 duel
# 172 duke
# 760 dull
# 592 dumb
# 133 dump
# 115 duo
# 57 durat
# 86 dust
# 102 dutch
# 136 duti
# 85 duval
# 2189 dvd
# 60 dwarf
# 56 dwell
# 55 dylan
# 155 dynam
# 82 dysfunct
# 81 eager
# 186 ear
# 88 earl
# 1437 earli
# 606 earlier
# 212 earn
# 58 earnest
# 836 earth
# 107 eas
# 723 easi
# 122 easier
# 816 easili
# 142 east
# 81 eastern
# 127 eastwood
# 561 eat
# 87 eaten
# 70 ebert
# 119 eccentr
# 101 echo
# 85 econom
# 314 ed
# 330 eddi
# 464 edg
# 86 edgar
# 76 edgi
# 98 edi
# 1121 edit
# 131 editor
# 254 educ
# 213 edward
# 142 eeri
# 3246 effect
# 66 effici
# 936 effort
# 67 egg
# 135 ego
# 192 eight
# 112 eighti
# 60 einstein
# 1660 either
# 70 el
# 140 elabor
# 108 elderli
# 118 elect
# 128 electr
# 63 electron
# 113 eleg
# 1065 element
# 127 eleph
# 157 elev
# 58 eleven
# 64 eli
# 100 elimin
# 64 elit
# 146 elizabeth
# 108 ellen
# 81 elm
# 1818 els
# 119 elsewher
# 142 elvi
# 123 elvira
# 146 em
# 57 embark
# 472 embarrass
# 60 embodi
# 98 embrac
# 216 emerg
# 109 emili
# 197 emma
# 1547 emot
# 74 empathi
# 79 emperor
# 78 emphas
# 92 emphasi
# 119 empir
# 199 employ
# 83 employe
# 283 empti
# 81 en
# 63 enabl
# 104 enchant
# 344 encount
# 169 encourag
# 8744 end
# 143 endear
# 212 endless
# 56 endlessli
# 202 endur
# 283 enemi
# 59 energet
# 288 energi
# 77 enforc
# 517 engag
# 137 engin
# 280 england
# 910 english
# 84 engross
# 159 enhanc
# 3897 enjoy
# 91 enlighten
# 61 enlist
# 137 enorm
# 3123 enough
# 138 ensembl
# 155 ensu
# 94 ensur
# 403 enter
# 93 enterpris
# 2564 entertain
# 71 enthral
# 75 enthusiasm
# 118 enthusiast
# 1801 entir
# 67 entitl
# 67 entranc
# 169 entri
# 181 environ
# 337 epic
# 2410 episod
# 57 epitom
# 585 equal
# 99 equip
# 83 equival
# 81 er
# 576 era
# 234 eric
# 54 erika
# 192 erot
# 81 errol
# 157 error
# 807 escap
# 2270 especi
# 54 esquir
# 128 essenc
# 392 essenti
# 324 establish
# 121 estat
# 65 esther
# 60 estrang
# 97 et
# 1091 etc
# 137 etern
# 80 ethan
# 54 ethic
# 90 ethnic
# 69 eugen
# 196 europ
# 67 europa
# 309 european
# 124 eva
# 105 eve
# 61 evelyn
# 11683 even
# 1187 event
# 710 eventu
# 5469 ever
# 3616 everi
# 379 everybodi
# 154 everyday
# 2020 everyon
# 2085 everyth
# 170 everywher
# 385 evid
# 1344 evil
# 114 evok
# 59 evolut
# 108 evolv
# 424 ex
# 178 exact
# 898 exactli
# 181 exagger
# 177 examin
# 1422 exampl
# 2028 excel
# 1670 except
# 185 excess
# 124 exchang
# 910 excit
# 71 exclus
# 450 excus
# 612 execut
# 133 exercis
# 76 exhaust
# 101 exhibit
# 958 exist
# 92 exit
# 56 exorcist
# 96 exot
# 85 expand
# 2702 expect
# 72 expedit
# 186 expens
# 1412 experi
# 227 experienc
# 95 experiment
# 205 expert
# 944 explain
# 303 explan
# 108 explicit
# 157 explod
# 449 exploit
# 441 explor
# 270 explos
# 206 expos
# 73 exposit
# 81 exposur
# 633 express
# 77 exquisit
# 153 extend
# 79 extens
# 160 extent
# 66 exterior
# 500 extra
# 164 extraordinari
# 1321 extrem
# 1991 eye
# 106 eyr
# 72 fabric
# 165 fabul
# 2063 face
# 169 facial
# 65 facil
# 3399 fact
# 249 factor
# 141 factori
# 172 fade
# 1357 fail
# 264 failur
# 63 faint
# 454 fair
# 54 fairbank
# 193 fairi
# 528 fairli
# 442 faith
# 477 fake
# 115 falk
# 1800 fall
# 143 fallen
# 201 fals
# 247 fame
# 3138 famili
# 510 familiar
# 688 famou
# 3040 fan
# 101 fanat
# 129 fanci
# 679 fantasi
# 764 fantast
# 2717 far
# 114 farc
# 213 fare
# 123 farm
# 94 farmer
# 81 farrel
# 71 fart
# 515 fascin
# 65 fascist
# 484 fashion
# 818 fast
# 89 faster
# 260 fat
# 204 fatal
# 296 fate
# 1973 father
# 312 fault
# 289 favor
# 1306 favorit
# 110 favour
# 341 favourit
# 156 fay
# 132 fbi
# 666 fear
# 57 feast
# 63 feat
# 1715 featur
# 84 fed
# 167 feed
# 4773 feel
# 212 feet
# 69 felix
# 322 fell
# 382 fellow
# 1373 felt
# 927 femal
# 62 feminin
# 89 feminist
# 75 femm
# 78 fenc
# 131 fest
# 429 festiv
# 119 fetch
# 112 fever
# 600 fi
# 127 fianc
# 639 fiction
# 77 fido
# 337 field
# 114 fifteen
# 58 fifth
# 131 fifti
# 1850 fight
# 137 fighter
# 1076 figur
# 129 file
# 832 fill
# 68 filler
# 43428 film
# 862 filmmak
# 65 filth
# 56 filthi
# 2861 final
# 69 financ
# 130 financi
# 4916 find
# 1235 fine
# 238 finest
# 167 finger
# 734 finish
# 818 fire
# 80 firm
# 60 firmli
# 8221 first
# 81 firstli
# 221 fish
# 59 fishburn
# 122 fisher
# 120 fist
# 777 fit
# 872 five
# 151 fix
# 61 flag
# 72 flair
# 105 flame
# 236 flash
# 372 flashback
# 60 flashi
# 537 flat
# 64 flavor
# 589 flaw
# 113 flawless
# 81 flee
# 76 fleet
# 290 flesh
# 625 fli
# 1475 flick
# 175 flight
# 115 flip
# 64 flirt
# 131 float
# 66 flock
# 57 flood
# 281 floor
# 140 flop
# 87 florida
# 245 flow
# 107 flower
# 63 fluff
# 60 fluid
# 137 flynn
# 457 focu
# 432 focus
# 77 fog
# 57 foil
# 418 folk
# 2047 follow
# 117 fond
# 96 fonda
# 66 fontain
# 296 food
# 356 fool
# 62 foolish
# 257 foot
# 577 footag
# 211 footbal
# 108 forbidden
# 1396 forc
# 290 ford
# 246 foreign
# 187 forest
# 360 forev
# 732 forget
# 190 forgett
# 229 forgiv
# 55 forgiven
# 158 forgot
# 319 forgotten
# 878 form
# 189 format
# 451 former
# 331 formula
# 170 forth
# 140 forti
# 327 fortun
# 656 forward
# 182 foster
# 72 fought
# 104 foul
# 2377 found
# 55 foundat
# 829 four
# 162 fourth
# 334 fox
# 71 foxx
# 65 fragil
# 385 frame
# 270 franc
# 144 franchis
# 87 franci
# 116 francisco
# 92 franco
# 435 frank
# 80 frankenstein
# 86 franki
# 230 frankli
# 61 frantic
# 259 freak
# 54 freaki
# 283 fred
# 285 freddi
# 652 free
# 221 freedom
# 157 freeman
# 84 freez
# 718 french
# 228 frequent
# 366 fresh
# 97 fri
# 182 friday
# 2926 friend
# 183 friendli
# 289 friendship
# 65 fright
# 272 frighten
# 62 frog
# 574 front
# 65 frontier
# 294 frustrat
# 259 fu
# 69 fuel
# 110 fulci
# 145 fulfil
# 1629 full
# 78 fuller
# 389 fulli
# 2465 fun
# 136 function
# 101 fund
# 73 fundament
# 95 funer
# 3866 funni
# 160 funnier
# 324 funniest
# 77 furi
# 76 furiou
# 96 furthermor
# 842 futur
# 109 futurist
# 106 fx
# 179 ga
# 67 gabl
# 110 gabriel
# 133 gadget
# 373 gag
# 236 gain
# 85 gal
# 63 galaxi
# 83 gambl
# 1505 game
# 102 gandhi
# 434 gang
# 318 gangster
# 88 gap
# 409 garbag
# 96 garbo
# 164 garden
# 246 gari
# 54 garland
# 103 garner
# 66 gasp
# 119 gate
# 167 gather
# 1098 gave
# 598 gay
# 102 gear
# 71 geek
# 55 geisha
# 389 gem
# 96 gender
# 261 gene
# 1826 gener
# 59 genet
# 62 geni
# 399 geniu
# 1249 genr
# 108 gentl
# 77 gentleman
# 57 gentlemen
# 450 genuin
# 852 georg
# 88 gerard
# 65 gere
# 545 german
# 205 germani
# 77 gestur
# 12764 get
# 57 ghetto
# 607 ghost
# 108 giallo
# 403 giant
# 228 gift
# 80 giggl
# 57 gilbert
# 64 gilliam
# 69 gillian
# 81 gimmick
# 67 gina
# 94 ginger
# 3684 girl
# 626 girlfriend
# 5221 give
# 1680 given
# 398 glad
# 94 glamor
# 74 glanc
# 60 glare
# 209 glass
# 118 glenn
# 192 glimps
# 102 global
# 73 globe
# 141 glori
# 64 glorifi
# 93 gloriou
# 121 glover
# 112 glow
# 55 glu
# 8431 go
# 172 goal
# 1131 god
# 114 godfath
# 87 godzilla
# 2237 goe
# 93 goer
# 278 gold
# 112 goldberg
# 60 goldblum
# 240 golden
# 64 goldsworthi
# 684 gone
# 223 gonna
# 13877 good
# 65 goof
# 149 goofi
# 236 gordon
# 943 gore
# 334 gorgeou
# 211 gori
# 3244 got
# 126 gothic
# 125 gotta
# 260 gotten
# 418 govern
# 250 grab
# 372 grace
# 441 grade
# 124 gradual
# 116 graduat
# 84 graham
# 67 graini
# 297 grand
# 93 grandfath
# 119 grandmoth
# 428 grant
# 402 graphic
# 113 grasp
# 54 grass
# 130 grate
# 223 gratuit
# 197 grave
# 123 gray
# 88 grayson
# 8244 great
# 149 greater
# 665 greatest
# 131 greatli
# 81 greed
# 86 greedi
# 114 greek
# 420 green
# 57 greet
# 70 greg
# 70 gregori
# 226 grew
# 150 grey
# 70 grief
# 99 griffith
# 185 grim
# 72 grin
# 92 grinch
# 230 grip
# 183 gritti
# 60 groan
# 213 gross
# 81 grotesqu
# 422 ground
# 1048 group
# 603 grow
# 228 grown
# 55 growth
# 69 grudg
# 157 gruesom
# 156 guarante
# 237 guard
# 1406 guess
# 188 guest
# 192 guid
# 132 guilt
# 174 guilti
# 65 guin
# 76 guitar
# 787 gun
# 100 gundam
# 59 gunga
# 202 gut
# 3965 guy
# 59 gypo
# 176 ha
# 81 habit
# 125 hack
# 55 hackman
# 71 hackney
# 55 hadley
# 57 hain
# 538 hair
# 99 hal
# 1889 half
# 156 halfway
# 220 hall
# 236 halloween
# 74 hallucin
# 127 ham
# 122 hamilton
# 142 hamlet
# 132 hammer
# 65 hammi
# 69 han
# 1998 hand
# 58 handicap
# 472 handl
# 211 handsom
# 404 hang
# 202 hank
# 62 hapless
# 3267 happen
# 1031 happi
# 138 happili
# 68 hara
# 2415 hard
# 89 hardcor
# 103 harder
# 160 hardi
# 559 hardli
# 55 harlow
# 111 harm
# 64 harmless
# 60 harold
# 668 harri
# 55 harriet
# 63 harrison
# 196 harsh
# 92 hart
# 94 hartley
# 96 harvey
# 257 hat
# 1171 hate
# 106 hatr
# 472 haunt
# 129 hawk
# 80 hay
# 56 hayworth
# 102 hbo
# 1891 head
# 66 headach
# 83 heal
# 120 health
# 55 healthi
# 65 heap
# 969 hear
# 1006 heard
# 1531 heart
# 87 heartbreak
# 70 heartfelt
# 60 heartwarm
# 140 heat
# 309 heaven
# 468 heavi
# 159 heavili
# 207 heck
# 84 heel
# 137 height
# 71 heist
# 352 held
# 133 helen
# 116 helicopt
# 921 hell
# 83 hello
# 59 helm
# 2520 help
# 74 helpless
# 145 henc
# 392 henri
# 63 hepburn
# 57 herd
# 54 herman
# 1272 hero
# 119 heroic
# 325 heroin
# 86 hesit
# 129 heston
# 375 hey
# 313 hidden
# 379 hide
# 100 hideou
# 1985 high
# 248 higher
# 100 highest
# 1047 highli
# 343 highlight
# 59 highway
# 60 hilar
# 973 hilari
# 345 hill
# 55 hindi
# 288 hint
# 176 hip
# 153 hippi
# 377 hire
# 517 histor
# 1205 histori
# 57 historian
# 1349 hit
# 192 hitchcock
# 276 hitler
# 70 hk
# 117 ho
# 159 hoffman
# 64 hokey
# 942 hold
# 488 hole
# 113 holi
# 159 holiday
# 106 holli
# 101 hollow
# 1735 hollywood
# 175 holm
# 57 holocaust
# 134 homag
# 1780 home
# 140 homeless
# 100 homer
# 99 homicid
# 153 homosexu
# 435 honest
# 87 honesti
# 420 honestli
# 179 hong
# 229 honor
# 58 honour
# 182 hood
# 255 hook
# 66 hooker
# 59 hoot
# 116 hop
# 2304 hope
# 91 hopeless
# 71 hopelessli
# 68 hopkin
# 93 hopper
# 72 horn
# 57 horni
# 146 horrend
# 1278 horribl
# 103 horrid
# 155 horrif
# 139 horrifi
# 3380 horror
# 390 hors
# 348 hospit
# 189 host
# 69 hostag
# 61 hostil
# 637 hot
# 389 hotel
# 1968 hour
# 2120 hous
# 84 household
# 67 housewif
# 238 howard
# 3240 howev
# 57 howl
# 61 http
# 122 hudson
# 64 hug
# 909 huge
# 176 hugh
# 126 huh
# 73 hulk
# 79 hum
# 2098 human
# 92 humbl
# 98 humili
# 1423 humor
# 412 humour
# 273 hundr
# 88 hung
# 73 hungri
# 392 hunt
# 289 hunter
# 463 hurt
# 1007 husband
# 63 huston
# 55 hybrid
# 83 hyde
# 198 hype
# 77 hypnot
# 169 hyster
# 120 ian
# 285 ice
# 171 icon
# 60 id
# 2384 idea
# 192 ideal
# 317 ident
# 181 identifi
# 58 ideolog
# 423 idiot
# 65 idol
# 54 ie
# 518 ignor
# 323 ii
# 124 iii
# 356 ill
# 92 illeg
# 95 illog
# 56 illus
# 143 illustr
# 84 im
# 782 imag
# 169 imageri
# 1406 imagin
# 651 imdb
# 189 imit
# 66 immatur
# 488 immedi
# 149 immens
# 71 immers
# 102 immigr
# 88 immort
# 367 impact
# 100 imperson
# 126 implaus
# 131 impli
# 68 implic
# 1004 import
# 111 importantli
# 69 impos
# 500 imposs
# 1341 impress
# 72 improb
# 332 improv
# 82 improvis
# 55 impuls
# 75 inabl
# 60 inaccur
# 58 inaccuraci
# 92 inan
# 101 inappropri
# 55 incarn
# 157 incid
# 105 incident
# 1824 includ
# 59 inclus
# 133 incoher
# 116 incompet
# 89 incomprehens
# 111 inconsist
# 81 incorpor
# 57 incorrect
# 100 increas
# 119 increasingli
# 1094 incred
# 653 inde
# 370 independ
# 199 indi
# 158 india
# 477 indian
# 210 indic
# 79 indiffer
# 380 individu
# 135 induc
# 161 indulg
# 390 industri
# 175 inept
# 211 inevit
# 126 inexplic
# 139 infam
# 97 infect
# 94 inferior
# 54 infinit
# 63 inflict
# 324 influenc
# 62 info
# 542 inform
# 67 ingeni
# 118 ingredi
# 60 ingrid
# 165 inhabit
# 83 inher
# 93 inherit
# 387 initi
# 72 inject
# 63 injur
# 70 injuri
# 72 inmat
# 185 inner
# 537 innoc
# 131 innov
# 309 insan
# 55 insecur
# 112 insert
# 551 insid
# 290 insight
# 68 insipid
# 188 insist
# 147 inspector
# 739 inspir
# 174 instal
# 308 instanc
# 95 instant
# 115 instantli
# 1984 instead
# 139 instinct
# 98 institut
# 63 instruct
# 84 instrument
# 399 insult
# 83 insur
# 163 integr
# 235 intellectu
# 800 intellig
# 441 intend
# 524 intens
# 547 intent
# 261 interact
# 4399 interest
# 61 interestingli
# 71 interior
# 340 intern
# 135 internet
# 263 interpret
# 97 interrupt
# 370 interview
# 89 intim
# 65 intric
# 492 intrigu
# 491 introduc
# 152 introduct
# 66 invad
# 94 invas
# 296 invent
# 124 invest
# 405 investig
# 192 invis
# 228 invit
# 1776 involv
# 81 iran
# 79 iraq
# 94 ireland
# 177 irish
# 375 iron
# 147 ironi
# 86 irrelev
# 307 irrit
# 72 isabel
# 69 ish
# 545 island
# 143 isol
# 70 israel
# 657 issu
# 143 itali
# 509 italian
# 129 item
# 54 iturbi
# 74 iv
# 858 jack
# 73 jacket
# 210 jacki
# 317 jackson
# 64 jade
# 174 jail
# 151 jake
# 57 jam
# 961 jame
# 121 jami
# 82 jan
# 595 jane
# 257 japan
# 645 japanes
# 115 jar
# 57 jare
# 299 jason
# 181 jaw
# 133 jay
# 99 jazz
# 116 jealou
# 57 jealousi
# 340 jean
# 56 jedi
# 285 jeff
# 103 jeffrey
# 97 jenni
# 237 jennif
# 125 jeremi
# 173 jerk
# 335 jerri
# 55 jersey
# 188 jess
# 151 jessica
# 254 jesu
# 126 jet
# 99 jew
# 76 jewel
# 153 jewish
# 60 jill
# 449 jim
# 255 jimmi
# 63 jo
# 276 joan
# 2242 job
# 73 jodi
# 611 joe
# 72 joel
# 124 joey
# 1975 john
# 277 johnni
# 175 johnson
# 342 join
# 1494 joke
# 62 joker
# 172 jon
# 89 jonathan
# 369 jone
# 61 jordan
# 208 joseph
# 71 josh
# 129 journalist
# 421 journey
# 300 joy
# 264 jr
# 61 judd
# 442 judg
# 76 judgment
# 101 judi
# 54 jule
# 202 juli
# 174 julia
# 79 julian
# 59 juliet
# 613 jump
# 79 june
# 187 jungl
# 82 junior
# 182 junk
# 54 juri
# 384 justic
# 199 justifi
# 91 justin
# 99 juvenil
# 127 kane
# 68 kansa
# 96 kapoor
# 100 karen
# 70 karl
# 130 karloff
# 265 kate
# 63 kathryn
# 108 kay
# 275 keaton
# 64 keen
# 2279 keep
# 77 keith
# 410 kelli
# 111 ken
# 100 kennedi
# 100 kenneth
# 63 kent
# 662 kept
# 257 kevin
# 453 key
# 80 khan
# 527 kick
# 2879 kid
# 70 kidman
# 251 kidnap
# 3392 kill
# 1521 killer
# 178 kim
# 2691 kind
# 252 kinda
# 938 king
# 93 kingdom
# 108 kirk
# 273 kiss
# 113 kitchen
# 66 kitti
# 68 kline
# 57 knee
# 800 knew
# 137 knife
# 107 knight
# 63 knightley
# 277 knock
# 6727 know
# 275 knowledg
# 950 known
# 78 kolchak
# 257 kong
# 127 korean
# 128 kubrick
# 118 kudo
# 72 kumar
# 222 kung
# 76 kurosawa
# 138 kurt
# 82 kyle
# 526 la
# 124 lab
# 117 label
# 84 labor
# 1638 lack
# 73 lacklust
# 68 ladder
# 57 laden
# 1030 ladi
# 145 laid
# 230 lake
# 681 lame
# 69 lampoon
# 62 lanc
# 528 land
# 192 landscap
# 158 lane
# 83 lang
# 513 languag
# 695 larg
# 129 larger
# 159 larri
# 2858 last
# 1187 late
# 1978 later
# 188 latest
# 82 latin
# 324 latter
# 2640 laugh
# 461 laughabl
# 226 laughter
# 111 launch
# 159 laura
# 110 laurel
# 66 laurenc
# 57 lauri
# 58 lavish
# 559 law
# 103 lawrenc
# 222 lawyer
# 166 lay
# 121 layer
# 170 lazi
# 211 le
# 2412 lead
# 274 leader
# 187 leagu
# 108 lean
# 104 leap
# 1241 learn
# 2813 least
# 2043 leav
# 70 lectur
# 301 led
# 748 lee
# 1905 left
# 272 leg
# 72 legaci
# 112 legal
# 342 legend
# 171 legendari
# 61 legitim
# 68 leigh
# 76 lemmon
# 92 lena
# 110 lend
# 318 length
# 82 lengthi
# 58 lennon
# 91 leo
# 102 leon
# 85 leonard
# 240 lesbian
# 155 lesli
# 1820 less
# 147 lesser
# 370 lesson
# 66 lester
# 2584 let
# 213 letter
# 1110 level
# 245 lewi
# 60 lex
# 95 li
# 54 liam
# 202 liber
# 75 liberti
# 127 librari
# 556 lie
# 6012 life
# 57 lifeless
# 118 lifestyl
# 174 lifetim
# 175 lift
# 1418 light
# 61 lighter
# 364 likabl
# 20524 like
# 80 likewis
# 167 lili
# 489 limit
# 161 lincoln
# 94 linda
# 72 lindsay
# 3113 line
# 60 linear
# 228 liner
# 85 linger
# 184 link
# 185 lion
# 160 lip
# 164 lisa
# 740 list
# 567 listen
# 102 lit
# 512 liter
# 69 literari
# 82 literatur
# 5813 littl
# 56 liu
# 4062 live
# 130 lloyd
# 155 lo
# 290 load
# 65 loath
# 952 local
# 621 locat
# 307 lock
# 78 logan
# 356 logic
# 62 loi
# 97 lol
# 408 london
# 252 lone
# 69 loneli
# 3200 long
# 423 longer
# 58 longest
# 8990 look
# 399 loos
# 337 lord
# 737 lose
# 203 loser
# 276 loss
# 1388 lost
# 4268 lot
# 111 lou
# 403 loud
# 219 loui
# 83 louis
# 199 lousi
# 143 lovabl
# 8147 love
# 624 lover
# 1704 low
# 228 lower
# 83 lowest
# 90 loyal
# 80 loyalti
# 138 luca
# 135 luci
# 58 lucil
# 244 luck
# 233 lucki
# 116 luckili
# 193 ludicr
# 145 lugosi
# 62 lui
# 61 luka
# 219 luke
# 88 lumet
# 55 lunat
# 90 lundgren
# 84 lure
# 66 lurk
# 76 lush
# 137 lust
# 59 luxuri
# 266 lynch
# 150 lyric
# 61 mabel
# 58 macabr
# 86 macarthur
# 417 machin
# 59 macho
# 101 maci
# 589 mad
# 7556 made
# 94 madonna
# 121 mafia
# 160 magazin
# 98 maggi
# 653 magic
# 57 magician
# 284 magnific
# 88 maid
# 89 mail
# 2080 main
# 346 mainli
# 184 mainstream
# 187 maintain
# 1086 major
# 13710 make
# 593 maker
# 189 makeup
# 652 male
# 100 mall
# 71 malon
# 58 mama
# 5460 man
# 1379 manag
# 111 manhattan
# 6086 mani
# 126 maniac
# 244 manipul
# 86 mankind
# 105 mann
# 520 manner
# 152 mansion
# 83 map
# 138 mar
# 77 marc
# 129 march
# 107 margaret
# 65 margin
# 712 mari
# 162 maria
# 102 marin
# 86 mario
# 68 marion
# 766 mark
# 317 market
# 59 marlon
# 830 marri
# 409 marriag
# 97 marshal
# 63 martha
# 92 marti
# 301 martial
# 86 martian
# 341 martin
# 284 marvel
# 317 mask
# 63 mason
# 228 mass
# 158 massacr
# 198 massiv
# 656 master
# 636 masterpiec
# 739 match
# 183 mate
# 753 materi
# 57 mathieu
# 176 matrix
# 230 matt
# 1245 matter
# 130 matthau
# 111 matthew
# 224 matur
# 184 max
# 3069 may
# 2093 mayb
# 69 mayhem
# 97 mayor
# 74 mccoy
# 80 mclaglen
# 61 mcqueen
# 57 meal
# 2702 mean
# 84 meander
# 140 meaning
# 97 meaningless
# 561 meant
# 223 meanwhil
# 151 measur
# 116 meat
# 166 mechan
# 278 media
# 182 medic
# 371 mediocr
# 136 medium
# 1452 meet
# 81 meg
# 114 mel
# 63 melissa
# 89 melodi
# 179 melodrama
# 112 melodramat
# 161 melt
# 791 member
# 644 memor
# 549 memori
# 1787 men
# 218 menac
# 501 mental
# 1405 mention
# 56 mentor
# 103 merci
# 485 mere
# 177 merit
# 66 mermaid
# 67 meryl
# 86 mesmer
# 717 mess
# 889 messag
# 61 messi
# 265 met
# 191 metal
# 130 metaphor
# 180 method
# 182 mexican
# 156 mexico
# 80 meyer
# 176 mgm
# 56 miami
# 1224 michael
# 212 michel
# 103 mickey
# 275 mid
# 887 middl
# 155 midnight
# 2623 might
# 82 mighti
# 124 miik
# 266 mike
# 117 mild
# 155 mildli
# 106 mildr
# 340 mile
# 422 militari
# 99 milk
# 139 mill
# 137 miller
# 512 million
# 80 millionair
# 64 milo
# 147 min
# 2142 mind
# 136 mindless
# 331 mine
# 196 mini
# 125 minim
# 77 minimum
# 63 miniseri
# 75 minist
# 439 minor
# 67 minu
# 3396 minut
# 113 miracl
# 63 miracul
# 222 mirror
# 159 miscast
# 206 miser
# 91 miseri
# 59 misfortun
# 69 misguid
# 84 mislead
# 1938 miss
# 71 missil
# 259 mission
# 572 mistak
# 101 mistaken
# 78 mistress
# 55 misunderstand
# 116 mitchel
# 679 mix
# 93 mixtur
# 78 miyazaki
# 78 mm
# 146 mob
# 59 mobil
# 54 mobster
# 115 mock
# 74 mode
# 368 model
# 65 moder
# 867 modern
# 58 modest
# 98 modesti
# 60 moe
# 63 mol
# 85 molli
# 331 mom
# 2487 moment
# 77 mon
# 2130 money
# 122 monk
# 209 monkey
# 87 monologu
# 76 monoton
# 838 monster
# 124 montag
# 85 montana
# 376 month
# 58 monti
# 60 monument
# 419 mood
# 103 moodi
# 281 moon
# 209 moor
# 595 moral
# 66 morbid
# 65 moreov
# 227 morgan
# 80 mormon
# 240 morn
# 178 moron
# 89 morri
# 86 mortal
# 847 mostli
# 1404 mother
# 455 motion
# 425 motiv
# 54 motorcycl
# 64 mount
# 287 mountain
# 156 mous
# 413 mouth
# 2195 move
# 297 movement
# 46698 movi
# 1565 mr
# 302 ms
# 170 mst
# 73 mtv
# 8782 much
# 83 muddl
# 117 multi
# 175 multipl
# 60 mum
# 91 mummi
# 83 mundan
# 139 muppet
# 1914 murder
# 206 murphi
# 76 murray
# 66 muscl
# 96 museum
# 3832 music
# 133 musician
# 104 muslim
# 2947 must
# 93 mutant
# 87 mute
# 57 mutil
# 63 mutual
# 92 myer
# 1286 mysteri
# 100 mystic
# 83 myth
# 65 mytholog
# 191 nail
# 207 naiv
# 394 nake
# 2627 name
# 221 nanci
# 414 narr
# 376 narrat
# 68 narrow
# 325 nasti
# 94 natali
# 65 nathan
# 491 nation
# 276 nativ
# 1386 natur
# 74 naughti
# 150 navi
# 267 nazi
# 130 nd
# 772 near
# 98 nearbi
# 740 nearli
# 141 neat
# 57 neatli
# 288 necessari
# 161 necessarili
# 150 neck
# 171 ned
# 3058 need
# 138 needless
# 380 neg
# 101 neglect
# 220 neighbor
# 141 neighborhood
# 121 neil
# 61 neill
# 486 neither
# 144 nelson
# 68 nemesi
# 97 neo
# 92 nephew
# 109 nerd
# 106 nerv
# 89 nervou
# 66 net
# 212 network
# 62 neurot
# 5835 never
# 199 nevertheless
# 3905 new
# 70 newcom
# 82 newli
# 66 newman
# 298 news
# 122 newspap
# 1541 next
# 2055 nice
# 86 nichola
# 106 nicholson
# 274 nick
# 82 nicol
# 73 nicola
# 67 niec
# 2099 night
# 58 nightclub
# 398 nightmar
# 149 nine
# 80 nineti
# 107 ninja
# 88 niro
# 140 nobl
# 405 nobodi
# 110 nod
# 411 noir
# 194 nois
# 68 nolan
# 66 nolt
# 382 nomin
# 804 non
# 946 none
# 143 nonetheless
# 335 nonsens
# 58 nope
# 78 norm
# 701 normal
# 109 norman
# 189 north
# 61 northern
# 174 nose
# 87 nostalg
# 86 nostalgia
# 266 notabl
# 189 notch
# 931 note
# 3876 noth
# 693 notic
# 128 notion
# 167 notori
# 69 novak
# 1042 novel
# 148 nowaday
# 403 nowher
# 118 nuanc
# 111 nuclear
# 180 nude
# 528 nuditi
# 90 numb
# 1275 number
# 254 numer
# 69 nun
# 148 nurs
# 151 nut
# 77 nyc
# 334 object
# 65 oblig
# 68 obligatori
# 159 obnoxi
# 55 obscen
# 167 obscur
# 250 observ
# 447 obsess
# 66 obstacl
# 95 obtain
# 956 obviou
# 1058 obvious
# 160 occas
# 401 occasion
# 55 occup
# 72 occupi
# 357 occur
# 107 ocean
# 622 odd
# 144 oddli
# 60 off
# 201 offend
# 242 offens
# 960 offer
# 865 offic
# 171 offici
# 1450 often
# 1297 oh
# 139 oil
# 931 ok
# 639 okay
# 56 ol
# 4152 old
# 590 older
# 60 oldest
# 229 oliv
# 96 olivi
# 89 olli
# 78 omen
# 57 omin
# 25066 one
# 81 onlin
# 303 onto
# 1920 open
# 257 oper
# 395 opera
# 953 opinion
# 60 oppon
# 446 opportun
# 146 oppos
# 290 opposit
# 89 oppress
# 57 optimist
# 101 option
# 88 orang
# 1033 order
# 244 ordinari
# 233 organ
# 134 orient
# 3655 origin
# 74 orlean
# 60 orphan
# 84 orson
# 878 oscar
# 72 othello
# 1418 other
# 609 otherwis
# 103 ought
# 68 out
# 120 outcom
# 55 outdat
# 97 outer
# 161 outfit
# 79 outing
# 67 outlaw
# 70 outlin
# 203 outrag
# 59 outright
# 588 outsid
# 381 outstand
# 146 overact
# 1298 overal
# 176 overcom
# 109 overdon
# 226 overli
# 67 overlong
# 219 overlook
# 101 overr
# 54 overshadow
# 163 overwhelm
# 126 owe
# 79 owen
# 141 own
# 294 owner
# 94 oz
# 1054 pace
# 62 pacif
# 176 pacino
# 355 pack
# 107 packag
# 129 pad
# 411 page
# 319 paid
# 1015 pain
# 484 paint
# 81 painter
# 300 pair
# 118 pal
# 75 palac
# 65 palanc
# 71 pale
# 57 palm
# 110 palma
# 86 paltrow
# 80 pamela
# 173 pan
# 107 panic
# 95 pant
# 258 paper
# 213 par
# 88 parad
# 67 paradis
# 134 parallel
# 69 paramount
# 86 paranoia
# 838 parent
# 364 pari
# 443 park
# 226 parker
# 289 parodi
# 4739 part
# 604 parti
# 90 partial
# 176 particip
# 673 particular
# 970 particularli
# 112 partli
# 319 partner
# 844 pass
# 75 passabl
# 71 passag
# 85 passeng
# 411 passion
# 1206 past
# 121 pat
# 227 path
# 442 pathet
# 71 patienc
# 248 patient
# 59 patricia
# 199 patrick
# 91 patriot
# 54 patron
# 85 pattern
# 795 paul
# 60 paula
# 127 pauli
# 98 paus
# 66 paxton
# 836 pay
# 62 pc
# 246 peac
# 127 peak
# 95 pearl
# 65 peck
# 54 pedestrian
# 54 pee
# 59 peer
# 57 pegg
# 97 pen
# 65 penn
# 73 penni
# 8480 peopl
# 55 pepper
# 146 per
# 78 perceiv
# 91 percept
# 1583 perfect
# 583 perfectli
# 4972 perform
# 1509 perhap
# 77 peril
# 764 period
# 61 perman
# 79 perpetu
# 114 perri
# 2977 person
# 131 persona
# 273 perspect
# 65 persuad
# 84 pervers
# 83 pervert
# 179 pet
# 69 pete
# 776 peter
# 79 petti
# 128 pg
# 77 phantom
# 58 phase
# 60 phenomen
# 63 phenomenon
# 59 phil
# 160 philip
# 134 phillip
# 134 philosoph
# 107 philosophi
# 369 phone
# 81 phoni
# 165 photo
# 351 photograph
# 364 photographi
# 107 phrase
# 463 physic
# 115 piano
# 987 pick
# 62 pickford
# 1777 pictur
# 142 pie
# 1782 piec
# 101 pierc
# 132 pig
# 222 pile
# 288 pilot
# 121 pin
# 83 pink
# 55 pioneer
# 107 pirat
# 115 pit
# 190 pitch
# 294 piti
# 176 pitt
# 61 pixar
# 2740 place
# 173 plagu
# 537 plain
# 760 plan
# 344 plane
# 493 planet
# 156 plant
# 140 plastic
# 60 plate
# 108 plausibl
# 7899 play
# 55 playboy
# 523 player
# 54 playwright
# 1132 pleas
# 206 pleasant
# 115 pleasantli
# 337 pleasur
# 598 plenti
# 77 plight
# 86 plod
# 6262 plot
# 595 plu
# 69 pocket
# 63 poe
# 88 poem
# 102 poetic
# 88 poetri
# 142 poignant
# 3815 point
# 469 pointless
# 125 poison
# 93 poke
# 91 pokemon
# 55 poker
# 93 polanski
# 76 pole
# 983 polic
# 71 policeman
# 76 polici
# 134 polish
# 885 polit
# 114 politician
# 83 ponder
# 154 pool
# 1723 poor
# 650 poorli
# 469 pop
# 99 popcorn
# 186 popul
# 574 popular
# 334 porn
# 92 porno
# 58 porter
# 126 portion
# 148 portrait
# 1725 portray
# 168 pose
# 71 posey
# 771 posit
# 278 possess
# 1723 possibl
# 526 post
# 177 poster
# 94 pot
# 644 potenti
# 63 potter
# 149 pound
# 89 pour
# 116 poverti
# 197 powel
# 1742 power
# 403 practic
# 265 prais
# 74 prank
# 100 pray
# 290 pre
# 86 preach
# 68 preachi
# 60 preced
# 107 preciou
# 141 precis
# 78 predat
# 99 predecessor
# 996 predict
# 339 prefer
# 163 pregnant
# 100 prejudic
# 140 premier
# 65 preming
# 670 premis
# 323 prepar
# 74 preposter
# 86 prequel
# 381 presenc
# 1383 present
# 81 preserv
# 254 presid
# 186 press
# 108 pressur
# 71 preston
# 188 presum
# 239 pretend
# 73 pretens
# 267 pretenti
# 3359 pretti
# 193 prevent
# 156 preview
# 571 previou
# 192 previous
# 83 prey
# 299 price
# 79 priceless
# 140 pride
# 235 priest
# 98 primari
# 99 primarili
# 196 prime
# 78 primit
# 283 princ
# 182 princess
# 156 princip
# 92 principl
# 224 print
# 171 prior
# 636 prison
# 264 privat
# 115 prize
# 169 pro
# 2629 probabl
# 2121 problem
# 83 proce
# 177 proceed
# 305 process
# 60 proclaim
# 1685 produc
# 2049 product
# 82 profan
# 83 profess
# 399 profession
# 211 professor
# 57 profil
# 75 profit
# 119 profound
# 347 program
# 82 programm
# 333 progress
# 644 project
# 116 prom
# 92 promin
# 548 promis
# 239 promot
# 58 promptli
# 134 proof
# 143 prop
# 179 propaganda
# 205 proper
# 151 properli
# 87 properti
# 60 propheci
# 61 prophet
# 66 proport
# 75 propos
# 176 prostitut
# 350 protagonist
# 287 protect
# 101 protest
# 160 proud
# 852 prove
# 893 provid
# 82 provoc
# 203 provok
# 65 ps
# 105 pseudo
# 58 psych
# 122 psychiatrist
# 90 psychic
# 250 psycho
# 326 psycholog
# 91 psychopath
# 105 psychot
# 590 public
# 112 publish
# 58 puerto
# 830 pull
# 107 pulp
# 98 pun
# 266 punch
# 155 punish
# 114 punk
# 140 puppet
# 67 puppi
# 200 purchas
# 668 pure
# 100 purpl
# 518 purpos
# 170 pursu
# 86 pursuit
# 389 push
# 2836 put
# 128 puzzl
# 63 quaid
# 122 qualifi
# 1391 qualiti
# 88 quarter
# 364 queen
# 174 quest
# 1188 question
# 316 quick
# 576 quickli
# 267 quiet
# 69 quietli
# 78 quinn
# 170 quirki
# 3401 quit
# 278 quot
# 94 rabbit
# 437 race
# 177 rachel
# 104 racial
# 137 racism
# 159 racist
# 66 radiat
# 92 radic
# 277 radio
# 151 rage
# 54 raid
# 267 rain
# 452 rais
# 63 raj
# 138 ralph
# 68 ram
# 93 rambl
# 97 rambo
# 105 ramon
# 72 rampag
# 212 ran
# 83 randi
# 57 randolph
# 329 random
# 76 randomli
# 297 rang
# 113 ranger
# 248 rank
# 78 rant
# 137 rap
# 500 rape
# 55 rapidli
# 85 rapist
# 685 rare
# 186 rat
# 2088 rate
# 2485 rather
# 89 ration
# 63 ratso
# 124 rave
# 166 raw
# 360 ray
# 85 raymond
# 65 razor
# 118 rd
# 495 reach
# 148 react
# 353 reaction
# 2520 read
# 128 reader
# 308 readi
# 4244 real
# 240 realis
# 261 realism
# 756 realist
# 963 realiti
# 1189 realiz
# 10605 realli
# 77 realm
# 68 rear
# 2897 reason
# 141 rebel
# 254 recal
# 478 receiv
# 967 recent
# 64 recit
# 308 recogn
# 80 recognis
# 84 recognit
# 68 recogniz
# 2065 recommend
# 526 record
# 110 recov
# 113 recreat
# 96 recruit
# 90 recycl
# 746 red
# 428 redeem
# 137 redempt
# 62 redneck
# 148 reduc
# 64 redund
# 153 reed
# 113 reel
# 121 reev
# 632 refer
# 338 reflect
# 198 refresh
# 319 refus
# 438 regard
# 111 regardless
# 86 region
# 80 regist
# 230 regret
# 268 regular
# 73 rehash
# 69 rehears
# 82 reid
# 81 reign
# 59 reincarn
# 188 reject
# 391 rel
# 681 relat
# 1216 relationship
# 147 relax
# 1717 releas
# 57 relentless
# 171 relev
# 222 reli
# 63 reliabl
# 229 relief
# 285 religi
# 239 religion
# 77 reluct
# 65 remad
# 743 remain
# 598 remak
# 512 remark
# 1839 rememb
# 837 remind
# 187 reminisc
# 314 remot
# 206 remov
# 68 renaiss
# 168 render
# 93 rendit
# 1128 rent
# 207 rental
# 418 repeat
# 107 repeatedli
# 140 repetit
# 319 replac
# 60 replay
# 93 repli
# 396 report
# 383 repres
# 78 represent
# 86 repress
# 55 repris
# 93 repuls
# 189 reput
# 408 requir
# 319 rescu
# 288 research
# 348 resembl
# 96 reserv
# 204 resid
# 170 resist
# 132 resolut
# 122 resolv
# 76 reson
# 128 resort
# 119 resourc
# 824 respect
# 99 respond
# 470 respons
# 1671 rest
# 127 restaur
# 165 restor
# 77 restrain
# 70 restrict
# 943 result
# 60 resum
# 92 resurrect
# 92 retain
# 173 retard
# 152 retir
# 58 retriev
# 1062 return
# 126 reunion
# 103 reunit
# 671 reveal
# 190 revel
# 499 reveng
# 121 revers
# 1992 review
# 102 reviv
# 90 revolt
# 180 revolut
# 96 revolutionari
# 260 revolv
# 175 reward
# 55 rewrit
# 127 rex
# 112 reynold
# 61 rhyme
# 69 rhythm
# 578 rich
# 844 richard
# 79 richardson
# 94 rick
# 110 rid
# 77 ridden
# 568 ride
# 88 rider
# 1039 ridicul
# 88 rifl
# 3224 right
# 473 ring
# 95 riot
# 523 rip
# 359 rise
# 197 risk
# 72 rita
# 61 ritchi
# 120 ritter
# 73 ritual
# 201 rival
# 307 river
# 104 rivet
# 423 road
# 60 roar
# 337 rob
# 76 robber
# 96 robberi
# 77 robbin
# 977 robert
# 233 robin
# 93 robinson
# 346 robot
# 147 rochest
# 956 rock
# 133 rocket
# 88 rocki
# 73 rod
# 345 roger
# 3885 role
# 606 roll
# 73 roller
# 107 roman
# 689 romanc
# 790 romant
# 68 rome
# 56 romeo
# 101 romero
# 93 romp
# 166 ron
# 59 ronald
# 82 roof
# 59 rooki
# 962 room
# 95 roommat
# 82 rooney
# 266 root
# 91 rope
# 247 rose
# 65 rosemari
# 72 ross
# 59 rot
# 88 roth
# 86 rotten
# 185 rough
# 343 round
# 73 rout
# 253 routin
# 139 row
# 214 roy
# 106 royal
# 69 rub
# 79 rubber
# 254 rubbish
# 88 rubi
# 86 rude
# 518 ruin
# 69 rukh
# 435 rule
# 67 rumor
# 2465 run
# 68 runner
# 97 rural
# 297 rush
# 210 russel
# 71 russia
# 318 russian
# 111 ruth
# 98 ruthless
# 195 ryan
# 75 sabrina
# 57 sacrif
# 147 sacrific
# 968 sad
# 127 sadist
# 515 sadli
# 252 safe
# 87 safeti
# 99 saga
# 2001 said
# 83 sailor
# 101 saint
# 232 sake
# 93 sale
# 119 salli
# 58 salman
# 63 salt
# 414 sam
# 55 samantha
# 80 sammi
# 109 samurai
# 201 san
# 73 sand
# 155 sandler
# 88 sandra
# 260 santa
# 89 sappi
# 170 sarah
# 54 sarcast
# 70 sassi
# 272 sat
# 165 satan
# 346 satir
# 376 satisfi
# 201 saturday
# 146 savag
# 1560 save
# 2865 saw
# 6764 say
# 209 scale
# 67 scandal
# 64 scar
# 671 scare
# 124 scarecrow
# 58 scarfac
# 911 scari
# 56 scariest
# 208 scenario
# 9574 scene
# 387 sceneri
# 70 schedul
# 167 scheme
# 64 schlock
# 1583 school
# 598 sci
# 513 scienc
# 115 scientif
# 436 scientist
# 122 scoobi
# 71 scoop
# 98 scope
# 1073 score
# 62 scorses
# 77 scotland
# 520 scott
# 88 scottish
# 119 scratch
# 619 scream
# 2536 screen
# 668 screenplay
# 198 screenwrit
# 169 screw
# 3021 script
# 77 scriptwrit
# 98 scroog
# 62 se
# 254 sea
# 145 seagal
# 76 seal
# 241 sean
# 472 search
# 977 season
# 262 seat
# 2099 second
# 65 secondari
# 95 secondli
# 671 secret
# 134 secretari
# 84 secretli
# 221 section
# 238 secur
# 114 seduc
# 94 seduct
# 12730 see
# 102 seed
# 58 seedi
# 388 seek
# 6502 seem
# 310 seemingli
# 6046 seen
# 345 segment
# 72 seldom
# 180 select
# 1055 self
# 121 selfish
# 383 sell
# 118 seller
# 192 semi
# 60 senat
# 387 send
# 62 senior
# 2188 sens
# 85 sensat
# 92 senseless
# 135 sensibl
# 217 sensit
# 61 sensual
# 365 sent
# 172 sentenc
# 290 sentiment
# 70 sentinel
# 263 separ
# 75 septemb
# 942 sequel
# 1474 sequenc
# 77 sergeant
# 3053 seri
# 412 serial
# 897 seriou
# 946 serious
# 555 serv
# 127 servant
# 253 servic
# 77 session
# 3682 set
# 178 settl
# 71 setup
# 323 seven
# 119 seventi
# 1515 sever
# 1582 sex
# 404 sexi
# 900 sexual
# 57 sg
# 95 sh
# 104 shade
# 290 shadow
# 177 shake
# 276 shakespear
# 78 shaki
# 125 shall
# 249 shallow
# 665 shame
# 79 shanghai
# 243 shape
# 508 share
# 162 shark
# 68 sharon
# 202 sharp
# 66 shatter
# 58 shave
# 93 shaw
# 91 shed
# 227 sheer
# 73 sheet
# 93 shelf
# 69 shell
# 77 shelley
# 56 shelter
# 64 shepherd
# 232 sheriff
# 127 shi
# 67 shield
# 138 shift
# 357 shine
# 415 ship
# 95 shirley
# 141 shirt
# 889 shock
# 75 shoddi
# 164 shoe
# 1023 shoot
# 78 shootout
# 327 shop
# 1792 short
# 71 shortcom
# 55 shorter
# 111 shortli
# 2695 shot
# 57 shotgun
# 147 shoulder
# 140 shout
# 80 shove
# 8921 show
# 149 showcas
# 78 showdown
# 167 shower
# 912 shown
# 66 shred
# 175 shut
# 94 sibl
# 482 sick
# 60 sicken
# 78 sid
# 1331 side
# 121 sidekick
# 56 sidewalk
# 173 sidney
# 360 sight
# 464 sign
# 58 signal
# 245 signific
# 142 silenc
# 415 silent
# 866 silli
# 129 silver
# 894 similar
# 85 similarli
# 73 simmon
# 275 simon
# 921 simpl
# 1772 simpli
# 83 simplic
# 98 simplist
# 130 simpson
# 78 simultan
# 198 sin
# 232 sinatra
# 2625 sinc
# 183 sincer
# 857 sing
# 322 singer
# 853 singl
# 143 sinist
# 168 sink
# 169 sir
# 79 sirk
# 85 sissi
# 895 sister
# 1144 sit
# 189 sitcom
# 263 site
# 1073 situat
# 351 six
# 107 sixti
# 186 size
# 67 skeptic
# 119 sketch
# 482 skill
# 235 skin
# 356 skip
# 132 skit
# 93 skull
# 311 sky
# 72 slam
# 194 slap
# 149 slapstick
# 84 slash
# 493 slasher
# 136 slaughter
# 165 slave
# 61 sleaz
# 152 sleazi
# 508 sleep
# 68 sleepwalk
# 109 slice
# 91 slick
# 91 slide
# 128 slight
# 113 slightest
# 500 slightli
# 65 slimi
# 126 slip
# 116 sloppi
# 1106 slow
# 382 slowli
# 83 slug
# 61 smack
# 1487 small
# 97 smaller
# 382 smart
# 112 smash
# 69 smell
# 409 smile
# 444 smith
# 248 smoke
# 114 smooth
# 163 snake
# 88 snap
# 60 snatch
# 134 sneak
# 60 sniper
# 90 snl
# 144 snow
# 54 snuff
# 280 soap
# 86 soccer
# 583 social
# 633 societi
# 80 soderbergh
# 272 soft
# 146 sold
# 719 soldier
# 214 sole
# 462 solid
# 93 solo
# 91 solut
# 212 solv
# 272 somebodi
# 65 someday
# 691 somehow
# 2131 someon
# 4628 someth
# 1152 sometim
# 871 somewhat
# 437 somewher
# 1350 son
# 1723 song
# 1110 soon
# 61 sooner
# 59 sophi
# 153 sophist
# 113 soprano
# 94 sore
# 704 sorri
# 1497 sort
# 54 sought
# 521 soul
# 2031 sound
# 708 soundtrack
# 78 soup
# 242 sourc
# 427 south
# 162 southern
# 113 soviet
# 68 sox
# 722 space
# 74 spacey
# 58 spade
# 71 spain
# 92 span
# 255 spanish
# 137 spare
# 133 spark
# 54 sparkl
# 60 spawn
# 1023 speak
# 89 speci
# 2050 special
# 238 specif
# 59 spectacl
# 231 spectacular
# 242 speech
# 276 speed
# 232 spell
# 55 spencer
# 742 spend
# 480 spent
# 262 spi
# 68 spice
# 89 spider
# 143 spielberg
# 136 spike
# 55 spill
# 181 spin
# 65 spinal
# 58 spine
# 60 spiral
# 682 spirit
# 151 spiritu
# 106 spit
# 169 spite
# 113 splatter
# 113 splendid
# 172 split
# 83 spock
# 361 spoil
# 887 spoiler
# 83 spoke
# 152 spoken
# 69 spontan
# 214 spoof
# 117 spooki
# 349 sport
# 532 spot
# 55 spout
# 56 spray
# 128 spread
# 63 spree
# 149 spring
# 66 springer
# 74 squad
# 123 squar
# 328 st
# 174 stab
# 90 stack
# 104 staff
# 847 stage
# 62 stair
# 72 stake
# 81 stale
# 157 stalk
# 87 stalker
# 86 stallon
# 130 stan
# 1311 stand
# 727 standard
# 67 standout
# 160 stanley
# 156 stanwyck
# 3964 star
# 196 stare
# 81 stargat
# 72 stark
# 3776 start
# 80 startl
# 951 state
# 210 statement
# 61 static
# 351 station
# 244 statu
# 1114 stay
# 64 steadi
# 541 steal
# 89 steam
# 151 steel
# 66 steer
# 56 stella
# 97 stellar
# 534 step
# 308 stephen
# 555 stereotyp
# 428 steve
# 311 steven
# 406 stewart
# 599 stick
# 130 stiff
# 5096 still
# 91 stiller
# 84 stilt
# 67 stimul
# 149 stink
# 106 stinker
# 89 stir
# 257 stock
# 104 stole
# 163 stolen
# 163 stomach
# 413 stone
# 121 stood
# 102 stoog
# 1402 stop
# 538 store
# 11854 stori
# 171 storm
# 720 storylin
# 175 storytel
# 777 straight
# 68 straightforward
# 88 strain
# 89 strand
# 1002 strang
# 215 stranger
# 67 stream
# 84 streep
# 871 street
# 95 streisand
# 272 strength
# 133 stress
# 255 stretch
# 110 strictli
# 365 strike
# 178 string
# 187 strip
# 68 strive
# 76 stroke
# 979 strong
# 122 stronger
# 63 strongest
# 204 strongli
# 119 struck
# 266 structur
# 628 struggl
# 72 stuart
# 317 stuck
# 57 stud
# 689 student
# 400 studi
# 620 studio
# 1071 stuff
# 201 stumbl
# 446 stun
# 264 stunt
# 1703 stupid
# 1598 style
# 146 stylish
# 57 stylist
# 58 styliz
# 345 sub
# 855 subject
# 69 sublim
# 59 submit
# 189 subplot
# 154 subsequ
# 211 substanc
# 58 substanti
# 77 substitut
# 60 subtext
# 213 subtitl
# 393 subtl
# 119 subtleti
# 57 subtli
# 54 subway
# 157 succe
# 252 succeed
# 1211 success
# 678 suck
# 66 sucker
# 232 sudden
# 477 suddenli
# 79 sue
# 722 suffer
# 83 suffic
# 69 suffici
# 69 sugar
# 684 suggest
# 321 suicid
# 517 suit
# 150 suitabl
# 171 sullivan
# 275 sum
# 55 summar
# 175 summari
# 339 summer
# 181 sun
# 176 sunday
# 67 sung
# 72 sunni
# 55 sunris
# 109 sunshin
# 470 super
# 607 superb
# 115 superbl
# 135 superfici
# 132 superhero
# 317 superior
# 295 superman
# 179 supernatur
# 113 suppli
# 1351 support
# 1710 suppos
# 329 supposedli
# 62 suprem
# 2775 sure
# 149 surf
# 193 surfac
# 55 surfer
# 64 surgeri
# 90 surpass
# 1823 surpris
# 420 surprisingli
# 219 surreal
# 347 surround
# 571 surviv
# 166 survivor
# 167 susan
# 451 suspect
# 120 suspend
# 916 suspens
# 105 suspici
# 72 suspicion
# 74 sustain
# 151 sutherland
# 81 swallow
# 161 swear
# 72 sweat
# 103 swedish
# 75 sweep
# 557 sweet
# 59 swept
# 170 swim
# 127 swing
# 206 switch
# 215 sword
# 308 symbol
# 85 sympath
# 211 sympathet
# 198 sympathi
# 93 synopsi
# 373 system
# 200 tabl
# 72 taboo
# 65 tack
# 74 tacki
# 86 tackl
# 71 tactic
# 83 tad
# 119 tag
# 88 tail
# 5989 take
# 887 taken
# 859 tale
# 1601 talent
# 1953 talk
# 97 talki
# 107 tall
# 118 tame
# 106 tank
# 162 tap
# 325 tape
# 60 tara
# 72 tarantino
# 286 target
# 247 tarzan
# 192 task
# 514 tast
# 72 tasteless
# 79 taught
# 77 tax
# 83 taxi
# 288 taylor
# 126 tea
# 281 teach
# 363 teacher
# 853 team
# 457 tear
# 68 teas
# 77 tech
# 464 technic
# 70 technicolor
# 254 techniqu
# 267 technolog
# 177 ted
# 200 tediou
# 487 teen
# 703 teenag
# 172 teeth
# 836 televis
# 2909 tell
# 76 temper
# 122 templ
# 96 tempt
# 764 ten
# 92 tenant
# 314 tend
# 75 tendenc
# 129 tender
# 138 tens
# 526 tension
# 556 term
# 106 termin
# 122 terri
# 1757 terribl
# 411 terrif
# 195 terrifi
# 125 territori
# 273 terror
# 169 terrorist
# 322 test
# 80 testament
# 204 texa
# 156 text
# 666 th
# 1025 thank
# 306 that
# 966 theater
# 319 theatr
# 230 theatric
# 1147 theme
# 234 theori
# 305 therefor
# 104 thick
# 146 thief
# 58 thiev
# 327 thin
# 7447 thing
# 8035 think
# 716 third
# 185 thirti
# 229 thoma
# 75 thompson
# 311 thoroughli
# 4122 though
# 3421 thought
# 279 thousand
# 108 thread
# 131 threat
# 268 threaten
# 2080 three
# 94 threw
# 420 thrill
# 952 thriller
# 145 throat
# 1205 throughout
# 675 throw
# 366 thrown
# 87 thru
# 57 thrust
# 382 thu
# 137 thug
# 166 thumb
# 76 thunderbird
# 67 tick
# 166 ticket
# 339 tie
# 72 tierney
# 104 tiger
# 183 tight
# 187 till
# 286 tim
# 55 timberlak
# 14680 time
# 116 timeless
# 54 timmi
# 79 timon
# 108 timothi
# 198 tini
# 102 tip
# 420 tire
# 80 tiresom
# 204 titan
# 1607 titl
# 1154 today
# 102 todd
# 62 toe
# 2017 togeth
# 127 toilet
# 63 token
# 56 tokyo
# 955 told
# 167 toler
# 675 tom
# 112 tomato
# 103 tommi
# 73 tomorrow
# 180 ton
# 538 tone
# 162 tongu
# 502 toni
# 84 tonight
# 990 took
# 137 tool
# 92 tooth
# 1772 top
# 208 topic
# 92 topless
# 110 torment
# 138 torn
# 59 toronto
# 439 tortur
# 123 toss
# 1760 total
# 1154 touch
# 455 tough
# 164 tour
# 84 tourist
# 823 toward
# 132 tower
# 1214 town
# 269 toy
# 97 trace
# 158 traci
# 542 track
# 163 trade
# 91 trademark
# 452 tradit
# 65 traffic
# 343 tragedi
# 339 tragic
# 100 trail
# 419 trailer
# 714 train
# 77 trait
# 70 transcend
# 160 transfer
# 294 transform
# 125 transit
# 271 translat
# 66 transplant
# 109 transport
# 355 trap
# 501 trash
# 92 trashi
# 62 trauma
# 73 traumat
# 514 travel
# 75 travesti
# 229 treasur
# 645 treat
# 228 treatment
# 251 tree
# 235 trek
# 164 tremend
# 89 trend
# 5745 tri
# 198 trial
# 60 triangl
# 101 tribe
# 130 tribut
# 339 trick
# 65 trier
# 68 trigger
# 205 trilog
# 107 trio
# 506 trip
# 73 tripe
# 68 tripl
# 128 trite
# 137 triumph
# 64 trivia
# 55 troma
# 101 troop
# 700 troubl
# 172 truck
# 2111 true
# 1569 truli
# 56 truman
# 349 trust
# 731 truth
# 81 tube
# 310 tune
# 79 tunnel
# 58 turd
# 168 turkey
# 54 turmoil
# 3511 turn
# 105 turner
# 55 turtl
# 2525 tv
# 105 twelv
# 297 twenti
# 347 twice
# 79 twilight
# 189 twin
# 1162 twist
# 6225 two
# 65 tyler
# 1271 type
# 804 typic
# 337 ugli
# 68 uh
# 203 uk
# 692 ultim
# 57 ultimatum
# 123 ultra
# 62 uma
# 178 un
# 220 unabl
# 54 unattract
# 76 unawar
# 130 unbear
# 504 unbeliev
# 306 uncl
# 149 uncomfort
# 179 unconvinc
# 70 uncov
# 59 uncut
# 60 undead
# 80 undeni
# 156 underground
# 81 underli
# 57 undermin
# 73 underneath
# 216 underr
# 80 underst
# 1939 understand
# 160 understood
# 55 undertak
# 56 underwat
# 57 underwear
# 68 underworld
# 90 undoubtedli
# 103 uneven
# 231 unexpect
# 74 unexpectedli
# 63 unexplain
# 75 unfair
# 222 unfold
# 133 unforgett
# 1384 unfortun
# 237 unfunni
# 92 unhappi
# 106 uniform
# 60 uniformli
# 74 unimagin
# 145 uninspir
# 227 unintent
# 187 uninterest
# 123 union
# 622 uniqu
# 324 unit
# 553 univers
# 271 unknown
# 79 unleash
# 608 unless
# 845 unlik
# 279 unnecessari
# 74 unorigin
# 114 unpleas
# 91 unpredict
# 74 unravel
# 88 unreal
# 214 unrealist
# 82 unrel
# 73 unsatisfi
# 68 unseen
# 99 unsettl
# 57 unsuspect
# 54 unsympathet
# 330 unusu
# 109 unwatch
# 248 up
# 120 updat
# 90 uplift
# 774 upon
# 150 upper
# 186 upset
# 195 urban
# 127 urg
# 3440 us
# 145 usa
# 4638 use
# 122 useless
# 150 user
# 78 ustinov
# 1758 usual
# 89 util
# 269 utter
# 420 utterli
# 90 uwe
# 156 vacat
# 63 vader
# 200 vagu
# 55 vain
# 77 valentin
# 76 valid
# 79 valley
# 908 valu
# 91 valuabl
# 589 vampir
# 461 van
# 79 vanc
# 59 vanessa
# 86 vanish
# 60 vaniti
# 115 vari
# 68 variat
# 176 varieti
# 536 variou
# 97 vast
# 133 vega
# 274 vehicl
# 78 vein
# 86 vengeanc
# 65 venom
# 100 ventur
# 76 verbal
# 59 verg
# 103 verhoeven
# 2173 version
# 99 versu
# 70 vet
# 221 veteran
# 274 vh
# 152 via
# 66 vibrant
# 90 vice
# 109 viciou
# 736 victim
# 188 victor
# 95 victori
# 223 victoria
# 56 victorian
# 1677 video
# 168 vietnam
# 1995 view
# 1838 viewer
# 63 viewpoint
# 61 vignett
# 60 vile
# 284 villag
# 839 villain
# 149 vincent
# 995 violenc
# 502 violent
# 208 virgin
# 84 virginia
# 66 virtu
# 247 virtual
# 129 viru
# 101 visibl
# 341 vision
# 449 visit
# 68 visitor
# 978 visual
# 75 vital
# 101 vivid
# 55 vividli
# 82 vocal
# 1355 voic
# 104 voight
# 86 volum
# 76 vomit
# 168 von
# 345 vote
# 90 voyag
# 256 vs
# 90 vulgar
# 119 vulner
# 84 wacki
# 71 wagner
# 1249 wait
# 88 waitress
# 239 wake
# 1239 walk
# 128 walken
# 109 walker
# 428 wall
# 111 wallac
# 84 walsh
# 56 walt
# 221 walter
# 224 wander
# 71 wang
# 144 wanna
# 125 wannab
# 6037 want
# 2150 war
# 126 ward
# 64 wardrob
# 332 warm
# 81 warmth
# 657 warn
# 187 warner
# 73 warrant
# 104 warren
# 183 warrior
# 137 wash
# 250 washington
# 2008 wast
# 12656 watch
# 271 watchabl
# 67 watcher
# 623 water
# 76 watson
# 279 wave
# 78 wax
# 7967 way
# 210 wayn
# 108 we
# 817 weak
# 55 weaker
# 90 weakest
# 102 wealth
# 134 wealthi
# 299 weapon
# 615 wear
# 60 weari
# 55 weather
# 71 weav
# 116 web
# 112 websit
# 301 wed
# 606 week
# 189 weekend
# 133 weight
# 624 weird
# 242 welcom
# 10011 well
# 93 wendi
# 66 wendigo
# 1324 went
# 220 werewolf
# 415 west
# 714 western
# 86 wet
# 58 whack
# 118 whale
# 75 what
# 661 whatev
# 277 whatsoev
# 90 wheel
# 54 wheelchair
# 246 whenev
# 131 wherea
# 804 whether
# 249 whilst
# 84 whine
# 88 whip
# 1402 white
# 183 whoever
# 2794 whole
# 71 wholli
# 88 whoopi
# 68 whore
# 884 whose
# 110 wick
# 338 wide
# 64 widescreen
# 144 widmark
# 179 widow
# 64 wield
# 1901 wife
# 78 wig
# 433 wild
# 141 wilder
# 72 wildli
# 349 will
# 199 willi
# 845 william
# 178 wilson
# 898 win
# 57 winchest
# 370 wind
# 290 window
# 240 wing
# 255 winner
# 211 winter
# 121 wipe
# 98 wire
# 81 wisdom
# 387 wise
# 1175 wish
# 678 wit
# 382 witch
# 741 within
# 2985 without
# 250 witti
# 97 wive
# 111 wizard
# 127 wolf
# 2574 woman
# 1663 women
# 3309 wonder
# 54 wong
# 88 wont
# 93 woo
# 629 wood
# 297 wooden
# 217 woodi
# 1656 word
# 91 wore
# 6426 work
# 266 worker
# 3588 world
# 91 worm
# 78 worn
# 302 worri
# 1319 wors
# 63 worship
# 2476 worst
# 2034 worth
# 329 worthi
# 117 worthless
# 166 worthwhil
# 11195 would
# 231 wound
# 408 wow
# 212 wrap
# 154 wreck
# 71 wrench
# 110 wrestl
# 59 wrestler
# 77 wretch
# 1903 write
# 1640 writer
# 1453 written
# 1694 wrong
# 511 wrote
# 62 wtf
# 76 ww
# 73 wwe
# 141 wwii
# 64 www
# 85 ya
# 97 yard
# 85 yawn
# 1389 ye
# 429 yeah
# 6279 year
# 71 yearn
# 173 yell
# 105 yellow
# 104 yesterday
# 2516 yet
# 77 yeti
# 56 yokai
# 741 york
# 3288 young
# 445 younger
# 67 youngest
# 315 youth
# 54 youtub
# 341 zero
# 79 zizek
# 1171 zombi
# 149 zone
# 63 zoom
# 56 zorro

# %%
print ("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit( train_data_features, train_sentiment )
# Out:
# Training the random forest...

# %%
# Read the test data
test = pd.read_csv("testData.tsv", header=0, delimiter="\t", \
                   quoting=3 )

# Verify that there are 25,000 rows and 2 columns
print (test.shape)

# Create an empty list and append the clean reviews one by one
num_reviews = len(test["review"])
clean_test_reviews = [] 

print ("Cleaning and parsing the test set movie reviews...\n")
for i in xrange(0,num_reviews):
    if( (i+1) % 1000 == 0 ):
        print ("Review %d of %d\n" % (i+1, num_reviews))
    clean_review = review_to_words( test["review"][i] )
    clean_test_reviews.append( clean_review )

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

# %%
# Use the random forest to make sentiment label predictions
predicted = forest.predict(test_data_features)

# %%
# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"id":test["id"], "sentiment":predicted} )

# Use pandas to write the comma-separated output file
output.to_csv( "Bag_of_Words_model.csv", index=False, quoting=3 )

# %%
from sklearn import metrics
expected=test_sentiment
print(metrics.classification_report(expected,predicted))
print(metrics.confusion_matrix(expected,predicted))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.51      0.66      0.57      1233
#           1       0.53      0.38      0.44      1267
#
# avg / total       0.52      0.52      0.51      2500
#
# [[814 419]
#  [789 478]]
